# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
sachchitkunichetty_rvf10k_path = kagglehub.dataset_download('sachchitkunichetty/rvf10k')

print('Data source import complete.')
# Out:
# Data source import complete.

# %%
#!pip install tensorflow numpy matplotlib seaborn scikit-learn opencv-python

# %%
# Setup and Configuration

import os
import warnings
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import seaborn as sns
from sklearn.model_selection import KFold
from tensorflow.keras.applications import Xception
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dropout, BatchNormalization, GlobalAveragePooling2D, Dense
from tensorflow.keras.optimizers import Adam
from typing import List, Tuple, Dict, Any
from tensorflow.keras import backend as K
import random
import glob
from tensorflow.keras.models import load_model
import math


CONFIG: Dict[str, Any] = {
    "SEED": 42,
    "IMAGE_SIZE": (224, 224),
    "BATCH_SIZE": 32,
    "N_FOLDS": 5,
    "DATA_DIR": r"/kaggle/input/rvf10k/rvf10k/train",
    "MODEL_SAVE_DIR": r"/kaggle/working/mymodels",

    "INITIAL_EPOCHS": 20,
    "FINE_TUNE_EPOCHS": 30,
    "INITIAL_LR": 0.001,
    "FINE_TUNE_LR": 1e-5,
    "L2_REG": 0.0001,
    "DROPOUT_RATE": 0.3,
    "ES_PATIENCE_PHASE1": 10,
    "RLR_PATIENCE_PHASE1": 4,
    "ES_PATIENCE_PHASE2": 15,
    "RLR_PATIENCE_PHASE2": 7,
    "MIN_LR": 1e-7,

    "PREDICTION_THRESHOLD": 0.5,
}

tf.random.set_seed(CONFIG["SEED"])
np.random.seed(CONFIG["SEED"])
random.seed(CONFIG["SEED"])
os.environ['PYTHONHASHSEED'] = str(CONFIG["SEED"])

os.makedirs(CONFIG["MODEL_SAVE_DIR"], exist_ok=True)

print("Environment and configuration loaded.")
# Out:
# Environment and configuration loaded.

# %%
# Data Loading and Preprocessing Functions

@tf.function
def apply_augmentation(image: tf.Tensor) -> tf.Tensor:
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    image = tf.image.random_saturation(image, lower=0.8, upper=1.2)
    image = tf.image.random_hue(image, max_delta=0.05)
    return image

@tf.function
def preprocess_image(filepath: str, label: tf.Tensor, image_size: Tuple[int, int]) -> Tuple[tf.Tensor, tf.Tensor]:
    try:
        img = tf.io.read_file(filepath)
        img = tf.image.decode_image(img, channels=3, expand_animations=False)
        img = tf.image.resize(img, image_size)
        img = tf.cast(img, tf.float32) / 255.0
        label = tf.reshape(tf.cast(label, tf.float32), (1,))
        return img, label
    except Exception as e:
        tf.print(f"Error processing image {filepath}: {e}")
        return tf.zeros(image_size + (3,), dtype=tf.float32), tf.constant([-1.0], dtype=tf.float32)

def load_data_paths(data_dir: str) -> Tuple[List[str], List[int]]:
    real_dir = os.path.join(data_dir, 'real')
    fake_dir = os.path.join(data_dir, 'fake')

    if not os.path.exists(real_dir) or not os.path.exists(fake_dir):
        raise ValueError(f"Data directory must contain 'real' and 'fake' subdirectories. Looked in {data_dir}")

    real_paths = glob.glob(os.path.join(real_dir, '*.jpg')) + glob.glob(os.path.join(real_dir, '*.png'))
    fake_paths = glob.glob(os.path.join(fake_dir, '*.jpg')) + glob.glob(os.path.join(fake_dir, '*.png'))

    if not real_paths and not fake_paths:
         raise ValueError(f"No images found in 'real' or 'fake' subdirectories within {data_dir}. Check DATA_DIR configuration.")


    image_paths = real_paths + fake_paths
    labels = [0] * len(real_paths) + [1] * len(fake_paths)

    combined = list(zip(image_paths, labels))
    random.shuffle(combined)
    image_paths, labels = zip(*combined)

    print(f"Found {len(real_paths)} real and {len(fake_paths)} fake images.")

    return list(image_paths), list(labels)


def create_dataset(image_paths: List[str], labels: List[int], config: Dict[str, Any], is_training: bool = True) -> tf.data.Dataset:
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))
    dataset = dataset.map(lambda x, y: preprocess_image(x, y, config["IMAGE_SIZE"]),
                          num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.filter(lambda x, y: tf.not_equal(tf.reduce_sum(y), -1.0))

    if is_training:
        # dataset = dataset.cache()
        dataset = dataset.shuffle(buffer_size=min(len(image_paths), 1000), seed=config["SEED"])
        dataset = dataset.map(lambda x, y: (apply_augmentation(x), y),
                              num_parallel_calls=tf.data.AUTOTUNE)

    dataset = dataset.batch(config["BATCH_SIZE"])
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

    return dataset

# %%
# Display Example Input Images

def display_example_images(data_dir: str, num_examples_per_class: int = 4):
    real_dir = os.path.join(data_dir, 'real')
    fake_dir = os.path.join(data_dir, 'fake')

    if not os.path.exists(real_dir) or not os.path.exists(fake_dir):
        print(f"Error: Data directories not found. Check {data_dir}")
        return

    real_paths = glob.glob(os.path.join(real_dir, '*.jpg')) + glob.glob(os.path.join(real_dir, '*.png'))
    fake_paths = glob.glob(os.path.join(fake_dir, '*.jpg')) + glob.glob(os.path.join(fake_dir, '*.png'))

    if not real_paths and not fake_paths:
        print(f"No images found in {data_dir}.")
        return

    num_real_display = min(num_examples_per_class, len(real_paths))
    num_fake_display = min(num_examples_per_class, len(fake_paths))

    display_paths = random.sample(real_paths, num_real_display) + random.sample(fake_paths, num_fake_display)
    display_labels = ['Real'] * num_real_display + ['Fake'] * num_fake_display

    combined_display = list(zip(display_paths, display_labels))
    random.shuffle(combined_display)
    display_paths, display_labels = zip(*combined_display)

    total_display = len(display_paths)
    if total_display == 0:
        print("No images selected for display.")
        return

    ncols = 4
    nrows = math.ceil(total_display / ncols)

    plt.figure(figsize=(ncols * 3, nrows * 3))

    for i, (img_path, label) in enumerate(zip(display_paths, display_labels)):
        plt.subplot(nrows, ncols, i + 1)
        try:
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            plt.imshow(img)
            plt.title(label)
            plt.axis('off')
        except Exception as e:
            print(f"Could not display image {img_path}: {e}")
            plt.text(0.5, 0.5, f"Error\n{label}", horizontalalignment='center', verticalalignment='center', fontsize=10)
            plt.axis('off')

    plt.tight_layout()
    plt.show()

print("Showing example images:")
display_example_images(CONFIG["DATA_DIR"], num_examples_per_class=4)
# Out:
# Showing example images:

# %%
# Model Architecture (XceptionNet)

def create_model(config: Dict[str, Any]) -> tf.keras.Model:
    base_model = Xception(
        include_top=False,
        weights='imagenet',
        input_shape=config["IMAGE_SIZE"] + (3,),
        pooling=None
    )
    base_model.trainable = False

    inputs = layers.Input(shape=config["IMAGE_SIZE"] + (3,), name="input_layer")
    x = base_model(inputs, training=False)

    x = GlobalAveragePooling2D(name="global_avg_pooling")(x)
    x = Dense(256, activation='relu', kernel_regularizer=l2(CONFIG["L2_REG"]), name="dense_1")(x)
    x = BatchNormalization(name="batch_norm_1")(x)
    x = Dropout(CONFIG["DROPOUT_RATE"], name="dropout_1")(x)

    x = Dense(128, activation='relu', kernel_regularizer=l2(CONFIG["L2_REG"]), name="dense_2")(x)
    x = BatchNormalization(name="batch_norm_2")(x)
    x = Dropout(CONFIG["DROPOUT_RATE"], name="dropout_2")(x)

    outputs = Dense(1, activation='sigmoid', name="output_layer")(x)
    model = models.Model(inputs=inputs, outputs=outputs, name="deepfake_classifier_xception")

    return model

# %%
# Training Function

def train_model(model: tf.keras.Model, train_ds: tf.data.Dataset, validation_ds: tf.data.Dataset,
                config: Dict[str, Any], fold_num: int) -> object:
    initial_epochs = config["INITIAL_EPOCHS"]
    fine_tune_epochs = config["FINE_TUNE_EPOCHS"]
    total_epochs = initial_epochs + fine_tune_epochs
    model_save_dir = config["MODEL_SAVE_DIR"]

    print(f"\n--- Fold {fold_num}: Phase 1 ---")
    model.compile(
        optimizer=Adam(learning_rate=config["INITIAL_LR"]),
        loss='binary_crossentropy',
        metrics=[
            'accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall'),
            tf.keras.metrics.F1Score(threshold=config["PREDICTION_THRESHOLD"], name='f1_score')
        ],
    )

    early_stopping_phase1 = EarlyStopping(monitor='val_loss', patience=config["ES_PATIENCE_PHASE1"], restore_best_weights=True, verbose=1)
    reduce_lr_phase1 = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=config["RLR_PATIENCE_PHASE1"], min_lr=config["MIN_LR"], verbose=1)
    checkpoint_filepath_phase1 = os.path.join(model_save_dir, f"fold_{fold_num}_phase1_best_model.keras")
    model_checkpoint_phase1 = ModelCheckpoint(filepath=checkpoint_filepath_phase1, save_best_only=True, monitor='val_loss', verbose=1)
    callbacks_phase1 = [early_stopping_phase1, reduce_lr_phase1, model_checkpoint_phase1]

    history_phase1 = model.fit(
        train_ds,
        epochs=initial_epochs,
        validation_data=validation_ds,
        callbacks=callbacks_phase1,
        verbose=1,
    )

    if os.path.exists(checkpoint_filepath_phase1):
         print(f"Loading best phase 1 weights for Fold {fold_num}.")
         model.load_weights(checkpoint_filepath_phase1)
    else:
         print(f"Warning: Phase 1 best weights not found for Fold {fold_num}.")


    print(f"\n Fold {fold_num}: Phase 2")
    model.trainable = True

    model.compile(
        optimizer=Adam(learning_rate=config["FINE_TUNE_LR"]),
        loss='binary_crossentropy',
        metrics=[
            'accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall'),
            tf.keras.metrics.F1Score(threshold=config["PREDICTION_THRESHOLD"], name='f1_score')
        ],
    )

    early_stopping_phase2 = EarlyStopping(monitor='val_loss', patience=config["ES_PATIENCE_PHASE2"], restore_best_weights=True, verbose=1)
    reduce_lr_phase2 = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=config["RLR_PATIENCE_PHASE2"], min_lr=config["MIN_LR"], verbose=1)
    checkpoint_filepath_phase2 = os.path.join(model_save_dir, f"fold_{fold_num}_phase2_best_model.keras")
    model_checkpoint_phase2 = ModelCheckpoint(filepath=checkpoint_filepath_phase2, save_best_only=True, monitor='val_loss', verbose=1)
    callbacks_phase2 = [early_stopping_phase2, reduce_lr_phase2, model_checkpoint_phase2]

    history_phase2 = model.fit(
        train_ds,
        epochs=total_epochs,
        initial_epoch=initial_epochs,
        validation_data=validation_ds,
        callbacks=callbacks_phase2,
        verbose=1,
    )

    combined_history = {}
    for key in history_phase1.history.keys():
        combined_history[key] = history_phase1.history[key] + history_phase2.history.get(key, [])

    class CombinedHistory:
        def __init__(self, history_dict):
            self.history = history_dict

    return CombinedHistory(combined_history)

# %%
# Evaluation and Plotting Functions

def evaluate_model(model: tf.keras.Model, validation_ds: tf.data.Dataset, config: Dict[str, Any], fold_num: Any) -> Tuple[np.ndarray, np.ndarray]:
    print(f"\n Evaluation for {('Fold ' + str(fold_num)) if isinstance(fold_num, int) else fold_num} ")

    y_true_list = []
    y_pred_list = []

    print("Collecting predictions...")
    for batch_images, batch_labels in validation_ds:
        y_true_list.extend(batch_labels.numpy().flatten())
        y_pred_batch = model.predict(batch_images, verbose=0)
        y_pred_list.extend(y_pred_batch.flatten().tolist())

    y_true = np.array(y_true_list)
    y_pred = np.array(y_pred_list)
    y_pred_binary = (y_pred > config["PREDICTION_THRESHOLD"]).astype(int)

    print("\n Classification Report:")
    print(classification_report(y_true, y_pred_binary, zero_division=0))

    print("\n Confusion Matrix:")
    cm = confusion_matrix(y_true, y_pred_binary)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
                xticklabels=['Real (0)', 'Fake (1)'], yticklabels=['Real (0)', 'Fake (1)'])
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title(f'{("Fold " + str(fold_num)) if isinstance(fold_num, int) else fold_num} Confusion Matrix')
    plt.show()

    return y_true, y_pred


def plot_history(history: object, fold_num: Any) -> None:
    hist = history.history

    if not hist:
        print(f"No history data to plot for {('Fold ' + str(fold_num)) if isinstance(fold_num, int) else fold_num}.")
        return

    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(hist.get('loss', []), label='Training Loss')
    plt.plot(hist.get('val_loss', []), label='Validation Loss')
    plt.title(f'{("Fold " + str(fold_num)) if isinstance(fold_num, int) else fold_num} Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, linestyle='--')

    plt.subplot(1, 2, 2)
    plt.plot(hist.get('accuracy', []), label='Training Accuracy')
    plt.plot(hist.get('val_accuracy', []), label='Validation Accuracy')
    plt.title(f'{("Fold " + str(fold_num)) if isinstance(fold_num, int) else fold_num} Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True, linestyle='--')

    plt.tight_layout()
    plt.show()


def plot_roc_curve(y_true: np.ndarray, y_pred: np.ndarray, fold_num: Any) -> None:
    if len(np.unique(y_true)) < 2:
        print(f"Skipping ROC plot for {('Fold ' + str(fold_num)) if isinstance(fold_num, int) else fold_num}: Only one class present in true labels.")
        return

    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Chance')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title(f'{("Fold " + str(fold_num)) if isinstance(fold_num, int) else fold_num} ROC Curve')
    plt.legend(loc="lower right")
    plt.grid(True, linestyle='--')
    plt.show()

# %%
# Prediction Functions

def load_trained_model(model_path: str) -> tf.keras.Model:
    if not os.path.exists(model_path):
        raise FileNotFoundError(f"Model file not found at {model_path}")
    print(f"Loading model from: {model_path}")
    model = load_model(model_path)
    print("Model loaded.")
    return model


def predict_single_image(model: tf.keras.Model, image_path: str, config: Dict[str, Any]) -> Tuple[float, str]:
    if not os.path.exists(image_path):
        print(f"Error: Image file not found at: {image_path}")
        plt.figure(figsize=(6, 6))
        plt.text(0.5, 0.5, "Error: Image not found", horizontalalignment='center', verticalalignment='center', fontsize=12, color='red')
        plt.axis('off')
        plt.title("Prediction Error")
        plt.show()
        return -1.0, "Error"

    try:
        img_tensor, _ = preprocess_image(tf.constant(image_path), tf.constant(0), config["IMAGE_SIZE"])
        img_tensor = tf.expand_dims(img_tensor, axis=0)
    except Exception as e:
         print(f"Error processing image {image_path} for prediction: {e}")
         plt.figure(figsize=(6, 6))
         plt.text(0.5, 0.5, f"Error processing image:\n{e}", horizontalalignment='center', verticalalignment='center', fontsize=10, color='red')
         plt.axis('off')
         plt.title("Image Processing Error")
         plt.show()
         return -1.0, "Error"

    prediction_prob = model.predict(img_tensor, verbose=0)[0][0]
    predicted_class = 'Fake' if prediction_prob > config["PREDICTION_THRESHOLD"] else 'Real'

    try:
        img_display = cv2.imread(image_path)
        if img_display is not None:
            img_display = cv2.cvtColor(img_display, cv2.COLOR_BGR2RGB)
            plt.figure(figsize=(6, 6))
            plt.imshow(img_display)
            plt.title(f"Prediction: {predicted_class} (Prob: {prediction_prob:.4f})")
            plt.axis('off')
            plt.show()
        else:
             print(f"Could not read image file for display: {image_path}")
             plt.figure(figsize=(6, 6))
             plt.text(0.5, 0.5, "Image Display Failed", horizontalalignment='center', verticalalignment='center', fontsize=12, color='red')
             plt.title("Prediction (Image Display Failed)")
             plt.axis('off')
             plt.show()

    except Exception as e:
        print(f"Could not display image for visualization: {e}")

    print(f"Prediction for {os.path.basename(image_path)}: Prob (Fake) = {prediction_prob:.4f}, Predicted = {predicted_class}")

    return float(prediction_prob), predicted_class


def predict_on_directory(model: tf.keras.Model, directory_path: str, config: Dict[str, Any]) -> List[Tuple[str, float, str]]:
    if not os.path.exists(directory_path) or not os.path.isdir(directory_path):
        print(f"Error: Directory not found: {directory_path}")
        return []

    image_files = glob.glob(os.path.join(directory_path, '*.jpg')) + glob.glob(os.path.join(directory_path, '*.png'))

    if not image_files:
        print(f"No images found in {directory_path}.")
        return []

    print(f"Found {len(image_files)} images in {directory_path}. Predicting...")

    dummy_labels = [0] * len(image_files)
    predict_ds = create_dataset(image_files, dummy_labels, config, is_training=False)
    predict_ds = predict_ds.map(lambda image, label: image)

    predictions = model.predict(predict_ds, verbose=1)

    results = []
    for i, prob in enumerate(predictions.flatten()):
        image_path = image_files[i]
        filename = os.path.basename(image_path)
        predicted_class = 'Fake' if prob > config["PREDICTION_THRESHOLD"] else 'Real'
        results.append((filename, float(prob), predicted_class))

    print("Predictions complete.")
    return results

# %%
# Main Execution Logic

def main(config: Dict[str, Any], mode: str = 'train') -> None:
    print(f"Starting {mode} mode")

    if mode == 'train':
        print("Preparing data for training...")
        try:
            image_paths, labels = load_data_paths(config["DATA_DIR"])
        except ValueError as e:
            print(f"Error loading data: {e}")
            return

        labels_np = np.array(labels)
        image_paths_np = np.array(image_paths)

        kf = KFold(n_splits=config["N_FOLDS"], shuffle=True, random_state=config["SEED"])

        all_y_true = []
        all_y_pred = []
        fold_metrics: Dict[str, List[float]] = {
            'accuracy': [], 'precision': [], 'recall': [], 'f1_score': [], 'auc': []
        }

        for fold_count, (train_index, val_index) in enumerate(kf.split(image_paths_np, labels_np), 1):
            print(f"\n\n Starting Fold {fold_count}/{config['N_FOLDS']} ")

            train_paths, train_labels = image_paths_np[train_index], labels_np[train_index]
            val_paths, val_labels = image_paths_np[val_index], labels_np[val_index]

            if len(np.unique(train_labels)) < 2:
                 print(f"Skipping Fold {fold_count}: Only one class in training set.")
                 continue
            if len(np.unique(val_labels)) < 2:
                 print(f"Warning: Only one class in validation set for Fold {fold_count}.")


            train_ds = create_dataset(list(train_paths), list(train_labels), config, is_training=True)
            validation_ds = create_dataset(list(val_paths), list(val_labels), config, is_training=False)

            model = create_model(config)
            history = train_model(model, train_ds, validation_ds, config, fold_count)

            best_model_path = os.path.join(config["MODEL_SAVE_DIR"], f"fold_{fold_count}_phase2_best_model.keras")
            if os.path.exists(best_model_path):
                 print(f"\n Loading best weights for Fold {fold_count} for evaluation.")
                 model.load_weights(best_model_path)
            else:
                 print(f"\n Warning: Best model weights not found for Fold {fold_count}.")

            y_true_fold, y_pred_fold = evaluate_model(model, validation_ds, config, fold_count)

            all_y_true.extend(y_true_fold)
            all_y_pred.extend(y_pred_fold)

            plot_history(history, fold_count)
            plot_roc_curve(y_true_fold, y_pred_fold, fold_count)

            y_pred_binary_fold = (y_pred_fold > config["PREDICTION_THRESHOLD"]).astype(int)
            report = classification_report(y_true_fold, y_pred_binary_fold, output_dict=True, zero_division=0)

            fold_metrics['accuracy'].append(report.get('accuracy', 0.0))
            if '1' in report:
                 fold_metrics['precision'].append(report['1']['precision'])
                 fold_metrics['recall'].append(report['1']['recall'])
                 fold_metrics['f1_score'].append(report['1']['f1-score'])
            else:
                 fold_metrics['precision'].append(0.0)
                 fold_metrics['recall'].append(0.0)
                 fold_metrics['f1_score'].append(0.0)


            if len(np.unique(y_true_fold)) > 1:
                fold_metrics['auc'].append(auc(*roc_curve(y_true_fold, y_pred_fold)[:2]))
            else:
                 fold_metrics['auc'].append(0.0)


            del model
            K.clear_session()
            print(f"\n Finished Fold {fold_count} \n")

        print(f"\n\n K-Fold Cross-Validation Summary")
        print("\n Average Performance Across Folds:")
        for metric_name, values in fold_metrics.items():
            if values:
                print(f"Average {metric_name.replace('_', '-').title()}: {np.mean(values):.4f} ± {np.std(values):.4f}")
            else:
                print(f"No data collected for {metric_name.replace('_', '-').title()}")

        print("\n Overall Metrics (Pooled Predictions):")
        if all_y_true:
            all_y_true_np = np.array(all_y_true)
            all_y_pred_np = np.array(all_y_pred)
            all_y_pred_binary_np = (all_y_pred_np > config["PREDICTION_THRESHOLD"]).astype(int)

            if len(np.unique(all_y_true_np)) > 1:
                 print(classification_report(all_y_true_np, all_y_pred_binary_np, zero_division=0))
                 cm_overall = confusion_matrix(all_y_true_np, all_y_pred_binary_np)
                 plt.figure(figsize=(8, 6))
                 sns.heatmap(cm_overall, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=['Real (0)', 'Fake (1)'], yticklabels=['Real (0)', 'Fake (1)'])
                 plt.xlabel('Predicted Labels')
                 plt.ylabel('True Labels')
                 plt.title('Overall Confusion Matrix')
                 plt.show()
                 plot_roc_curve(all_y_true_np, all_y_pred_np, fold_num='Overall Pooled')
            else:
                 print("Can't compute overall metrics: Only one class in pooled true labels.")
        else:
            print("No evaluation data collected.")

    elif mode == 'predict_dir':
        print("Running directory prediction...")
        model_to_use = os.path.join(config["MODEL_SAVE_DIR"], "fold_4_phase2_best_model.keras") # Update fold number if needed
        directory_to_predict = r"/kaggle/input/imagetest2/test2" # Update path if needed

        if not os.path.exists(model_to_use):
            print(f"Error: Model file not found at {model_to_use}.")
            return

        try:
            model = load_trained_model(model_to_use)
            results = predict_on_directory(model, directory_to_predict, config)
            if results:
                 print("\n Prediction Results")
                 for filename, prob, label in results:
                     print(f"{filename}: Prob (Fake) = {prob:.4f}, Predicted = {label}")
            else:
                 print("No predictions made.")
            del model
            K.clear_session()

        except (ValueError, FileNotFoundError) as e:
            print(f"Prediction Error: {e}")
        except Exception as e:
            print(f"An error occurred during directory prediction: {e}")

    else:
        print(f"Error: Unknown mode: {mode}. Use 'train' or 'predict_dir'.")

    print("\n Project Finished")

# %%
# Choose and Execute Project Mode

# Uncomment one of the lines below to run the desired mode

main(CONFIG, mode='train') # Run K-Fold Training (if you wanna train the model)

#Or,

# main(CONFIG, mode='predict_dir') # To Predict using trained model (predicting different dataset (which's not trained on) images)
# Out:
# Starting train mode
# Preparing data for training...
# Found 3500 real and 3500 fake images.
#
#
#  Starting Fold 1/5
#
# --- Fold 1: Phase 1 ---
# Epoch 1/20
#     175/Unknown 37s 127ms/step - accuracy: 0.6279 - f1_score: 0.6353 - loss: 0.8179 - precision: 0.6264 - recall: 0.6447
# Epoch 1: val_loss improved from inf to 0.61057, saving model to /kaggle/working/mymodels/fold_1_phase1_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 53s 221ms/step - accuracy: 0.6281 - f1_score: 0.6355 - loss: 0.8175 - precision: 0.6266 - recall: 0.6448 - val_accuracy: 0.7229 - val_f1_score: 0.7441 - val_loss: 0.6106 - val_precision: 0.6675 - val_recall: 0.8405 - learning_rate: 0.0010
# Epoch 2/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.6884 - f1_score: 0.6977 - loss: 0.6713 - precision: 0.6844 - recall: 0.7116
# Epoch 2: val_loss did not improve from 0.61057
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 31s 173ms/step - accuracy: 0.6885 - f1_score: 0.6977 - loss: 0.6712 - precision: 0.6844 - recall: 0.7116 - val_accuracy: 0.6893 - val_f1_score: 0.7372 - val_loss: 0.6479 - val_precision: 0.6199 - val_recall: 0.9091 - learning_rate: 0.0010
# Epoch 3/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.7273 - f1_score: 0.7305 - loss: 0.6090 - precision: 0.7235 - recall: 0.7378
# Epoch 3: val_loss improved from 0.61057 to 0.59245, saving model to /kaggle/working/mymodels/fold_1_phase1_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 34s 188ms/step - accuracy: 0.7273 - f1_score: 0.7306 - loss: 0.6090 - precision: 0.7235 - recall: 0.7378 - val_accuracy: 0.7271 - val_f1_score: 0.7453 - val_loss: 0.5925 - val_precision: 0.6743 - val_recall: 0.8331 - learning_rate: 0.0010
# Epoch 4/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7533 - f1_score: 0.7565 - loss: 0.5738 - precision: 0.7471 - recall: 0.7662
# Epoch 4: val_loss did not improve from 0.59245
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 35s 195ms/step - accuracy: 0.7532 - f1_score: 0.7565 - loss: 0.5738 - precision: 0.7471 - recall: 0.7662 - val_accuracy: 0.7279 - val_f1_score: 0.7593 - val_loss: 0.6115 - val_precision: 0.6590 - val_recall: 0.8957 - learning_rate: 0.0010
# Epoch 5/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.7723 - f1_score: 0.7747 - loss: 0.5472 - precision: 0.7611 - recall: 0.7894
# Epoch 5: val_loss improved from 0.59245 to 0.56543, saving model to /kaggle/working/mymodels/fold_1_phase1_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.7723 - f1_score: 0.7746 - loss: 0.5473 - precision: 0.7611 - recall: 0.7893 - val_accuracy: 0.7514 - val_f1_score: 0.7387 - val_loss: 0.5654 - val_precision: 0.7443 - val_recall: 0.7332 - learning_rate: 0.0010
# Epoch 6/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.7666 - f1_score: 0.7710 - loss: 0.5368 - precision: 0.7577 - recall: 0.7851
# Epoch 6: val_loss did not improve from 0.56543
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.7666 - f1_score: 0.7710 - loss: 0.5368 - precision: 0.7578 - recall: 0.7850 - val_accuracy: 0.7243 - val_f1_score: 0.6649 - val_loss: 0.6091 - val_precision: 0.7963 - val_recall: 0.5708 - learning_rate: 0.0010
# Epoch 7/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.7930 - f1_score: 0.7984 - loss: 0.5154 - precision: 0.7998 - recall: 0.7979
# Epoch 7: val_loss improved from 0.56543 to 0.55643, saving model to /kaggle/working/mymodels/fold_1_phase1_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.7929 - f1_score: 0.7984 - loss: 0.5154 - precision: 0.7997 - recall: 0.7979 - val_accuracy: 0.7607 - val_f1_score: 0.7531 - val_loss: 0.5564 - val_precision: 0.7449 - val_recall: 0.7615 - learning_rate: 0.0010
# Epoch 8/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.7871 - f1_score: 0.7902 - loss: 0.5099 - precision: 0.7715 - recall: 0.8100
# Epoch 8: val_loss did not improve from 0.55643
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.7871 - f1_score: 0.7902 - loss: 0.5099 - precision: 0.7716 - recall: 0.8100 - val_accuracy: 0.7314 - val_f1_score: 0.7599 - val_loss: 0.6148 - val_precision: 0.6648 - val_recall: 0.8867 - learning_rate: 0.0010
# Epoch 9/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8110 - f1_score: 0.8158 - loss: 0.4938 - precision: 0.8072 - recall: 0.8248
# Epoch 9: val_loss did not improve from 0.55643
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8110 - f1_score: 0.8158 - loss: 0.4938 - precision: 0.8072 - recall: 0.8248 - val_accuracy: 0.7707 - val_f1_score: 0.7659 - val_loss: 0.5639 - val_precision: 0.7500 - val_recall: 0.7824 - learning_rate: 0.0010
# Epoch 10/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8056 - f1_score: 0.8082 - loss: 0.4894 - precision: 0.8066 - recall: 0.8100
# Epoch 10: val_loss improved from 0.55643 to 0.54229, saving model to /kaggle/working/mymodels/fold_1_phase1_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.8055 - f1_score: 0.8082 - loss: 0.4894 - precision: 0.8066 - recall: 0.8100 - val_accuracy: 0.7857 - val_f1_score: 0.7869 - val_loss: 0.5423 - val_precision: 0.7517 - val_recall: 0.8256 - learning_rate: 0.0010
# Epoch 11/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8091 - f1_score: 0.8128 - loss: 0.4867 - precision: 0.8048 - recall: 0.8213
# Epoch 11: val_loss did not improve from 0.54229
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.8091 - f1_score: 0.8128 - loss: 0.4867 - precision: 0.8048 - recall: 0.8212 - val_accuracy: 0.7679 - val_f1_score: 0.7788 - val_loss: 0.5725 - val_precision: 0.7168 - val_recall: 0.8525 - learning_rate: 0.0010
# Epoch 12/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8122 - f1_score: 0.8149 - loss: 0.4832 - precision: 0.8084 - recall: 0.8217
# Epoch 12: val_loss did not improve from 0.54229
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8121 - f1_score: 0.8149 - loss: 0.4832 - precision: 0.8084 - recall: 0.8217 - val_accuracy: 0.7743 - val_f1_score: 0.7830 - val_loss: 0.5632 - val_precision: 0.7261 - val_recall: 0.8495 - learning_rate: 0.0010
# Epoch 13/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8224 - f1_score: 0.8261 - loss: 0.4716 - precision: 0.8172 - recall: 0.8355
# Epoch 13: val_loss did not improve from 0.54229
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8224 - f1_score: 0.8261 - loss: 0.4716 - precision: 0.8172 - recall: 0.8355 - val_accuracy: 0.7521 - val_f1_score: 0.7722 - val_loss: 0.5889 - val_precision: 0.6901 - val_recall: 0.8763 - learning_rate: 0.0010
# Epoch 14/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8217 - f1_score: 0.8236 - loss: 0.4751 - precision: 0.8134 - recall: 0.8343
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 14: val_loss did not improve from 0.54229
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.8217 - f1_score: 0.8236 - loss: 0.4751 - precision: 0.8134 - recall: 0.8343 - val_accuracy: 0.7529 - val_f1_score: 0.7136 - val_loss: 0.6075 - val_precision: 0.8026 - val_recall: 0.6423 - learning_rate: 0.0010
# Epoch 15/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8253 - f1_score: 0.8274 - loss: 0.4555 - precision: 0.8147 - recall: 0.8408
# Epoch 15: val_loss did not improve from 0.54229
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8253 - f1_score: 0.8275 - loss: 0.4554 - precision: 0.8148 - recall: 0.8408 - val_accuracy: 0.7793 - val_f1_score: 0.7829 - val_loss: 0.5557 - val_precision: 0.7407 - val_recall: 0.8301 - learning_rate: 5.0000e-04
# Epoch 16/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8511 - f1_score: 0.8543 - loss: 0.4198 - precision: 0.8488 - recall: 0.8604
# Epoch 16: val_loss improved from 0.54229 to 0.54022, saving model to /kaggle/working/mymodels/fold_1_phase1_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.8511 - f1_score: 0.8543 - loss: 0.4198 - precision: 0.8488 - recall: 0.8604 - val_accuracy: 0.7850 - val_f1_score: 0.7836 - val_loss: 0.5402 - val_precision: 0.7569 - val_recall: 0.8122 - learning_rate: 5.0000e-04
# Epoch 17/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8557 - f1_score: 0.8575 - loss: 0.4003 - precision: 0.8475 - recall: 0.8678
# Epoch 17: val_loss did not improve from 0.54022
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.8556 - f1_score: 0.8574 - loss: 0.4004 - precision: 0.8475 - recall: 0.8677 - val_accuracy: 0.7743 - val_f1_score: 0.7765 - val_loss: 0.5608 - val_precision: 0.7389 - val_recall: 0.8182 - learning_rate: 5.0000e-04
# Epoch 18/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8524 - f1_score: 0.8549 - loss: 0.3996 - precision: 0.8500 - recall: 0.8599
# Epoch 18: val_loss did not improve from 0.54022
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8524 - f1_score: 0.8549 - loss: 0.3996 - precision: 0.8501 - recall: 0.8599 - val_accuracy: 0.7757 - val_f1_score: 0.7650 - val_loss: 0.5626 - val_precision: 0.7684 - val_recall: 0.7615 - learning_rate: 5.0000e-04
# Epoch 19/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8539 - f1_score: 0.8570 - loss: 0.3964 - precision: 0.8475 - recall: 0.8668
# Epoch 19: val_loss did not improve from 0.54022
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8539 - f1_score: 0.8570 - loss: 0.3964 - precision: 0.8475 - recall: 0.8668 - val_accuracy: 0.7743 - val_f1_score: 0.7756 - val_loss: 0.5599 - val_precision: 0.7408 - val_recall: 0.8137 - learning_rate: 5.0000e-04
# Epoch 20/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8799 - f1_score: 0.8817 - loss: 0.3596 - precision: 0.8802 - recall: 0.8834
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 20: val_loss did not improve from 0.54022
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8798 - f1_score: 0.8816 - loss: 0.3597 - precision: 0.8801 - recall: 0.8833 - val_accuracy: 0.7886 - val_f1_score: 0.7781 - val_loss: 0.5727 - val_precision: 0.7828 - val_recall: 0.7735 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 16.
# Loading best phase 1 weights for Fold 1.
#
#  Fold 1: Phase 2
# Epoch 21/50
#     175/Unknown 41s 162ms/step - accuracy: 0.8600 - f1_score: 0.8639 - loss: 0.3880 - precision: 0.8439 - recall: 0.8852
# Epoch 21: val_loss improved from inf to 0.53953, saving model to /kaggle/working/mymodels/fold_1_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 54s 239ms/step - accuracy: 0.8600 - f1_score: 0.8639 - loss: 0.3880 - precision: 0.8439 - recall: 0.8852 - val_accuracy: 0.7829 - val_f1_score: 0.7771 - val_loss: 0.5395 - val_precision: 0.7648 - val_recall: 0.7899 - learning_rate: 1.0000e-05
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8659 - f1_score: 0.8679 - loss: 0.3884 - precision: 0.8600 - recall: 0.8762
# Epoch 22: val_loss did not improve from 0.53953
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.8659 - f1_score: 0.8679 - loss: 0.3884 - precision: 0.8600 - recall: 0.8762 - val_accuracy: 0.7829 - val_f1_score: 0.7791 - val_loss: 0.5406 - val_precision: 0.7603 - val_recall: 0.7988 - learning_rate: 1.0000e-05
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8649 - f1_score: 0.8679 - loss: 0.3819 - precision: 0.8572 - recall: 0.8791
# Epoch 23: val_loss did not improve from 0.53953
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.8649 - f1_score: 0.8680 - loss: 0.3819 - precision: 0.8572 - recall: 0.8791 - val_accuracy: 0.7857 - val_f1_score: 0.7835 - val_loss: 0.5402 - val_precision: 0.7594 - val_recall: 0.8092 - learning_rate: 1.0000e-05
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8577 - f1_score: 0.8602 - loss: 0.3909 - precision: 0.8538 - recall: 0.8670
# Epoch 24: val_loss did not improve from 0.53953
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8577 - f1_score: 0.8603 - loss: 0.3908 - precision: 0.8538 - recall: 0.8671 - val_accuracy: 0.7843 - val_f1_score: 0.7815 - val_loss: 0.5398 - val_precision: 0.7595 - val_recall: 0.8048 - learning_rate: 1.0000e-05
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8588 - f1_score: 0.8629 - loss: 0.3920 - precision: 0.8419 - recall: 0.8851
# Epoch 25: val_loss improved from 0.53953 to 0.53857, saving model to /kaggle/working/mymodels/fold_1_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.8589 - f1_score: 0.8630 - loss: 0.3919 - precision: 0.8420 - recall: 0.8851 - val_accuracy: 0.7843 - val_f1_score: 0.7808 - val_loss: 0.5386 - val_precision: 0.7610 - val_recall: 0.8018 - learning_rate: 1.0000e-05
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8734 - f1_score: 0.8754 - loss: 0.3776 - precision: 0.8720 - recall: 0.8792
# Epoch 26: val_loss did not improve from 0.53857
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.8733 - f1_score: 0.8754 - loss: 0.3776 - precision: 0.8720 - recall: 0.8792 - val_accuracy: 0.7821 - val_f1_score: 0.7788 - val_loss: 0.5391 - val_precision: 0.7585 - val_recall: 0.8003 - learning_rate: 1.0000e-05
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8576 - f1_score: 0.8621 - loss: 0.3819 - precision: 0.8467 - recall: 0.8785
# Epoch 27: val_loss did not improve from 0.53857
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8576 - f1_score: 0.8622 - loss: 0.3818 - precision: 0.8467 - recall: 0.8785 - val_accuracy: 0.7836 - val_f1_score: 0.7800 - val_loss: 0.5392 - val_precision: 0.7606 - val_recall: 0.8003 - learning_rate: 1.0000e-05
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8534 - f1_score: 0.8574 - loss: 0.3877 - precision: 0.8528 - recall: 0.8625
# Epoch 28: val_loss did not improve from 0.53857
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8534 - f1_score: 0.8574 - loss: 0.3876 - precision: 0.8528 - recall: 0.8626 - val_accuracy: 0.7843 - val_f1_score: 0.7808 - val_loss: 0.5394 - val_precision: 0.7610 - val_recall: 0.8018 - learning_rate: 1.0000e-05
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8694 - f1_score: 0.8725 - loss: 0.3704 - precision: 0.8553 - recall: 0.8905
# Epoch 29: val_loss improved from 0.53857 to 0.53826, saving model to /kaggle/working/mymodels/fold_1_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.8694 - f1_score: 0.8725 - loss: 0.3704 - precision: 0.8553 - recall: 0.8905 - val_accuracy: 0.7836 - val_f1_score: 0.7796 - val_loss: 0.5383 - val_precision: 0.7614 - val_recall: 0.7988 - learning_rate: 1.0000e-05
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8654 - f1_score: 0.8671 - loss: 0.3731 - precision: 0.8531 - recall: 0.8816
# Epoch 30: val_loss did not improve from 0.53826
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.8654 - f1_score: 0.8671 - loss: 0.3731 - precision: 0.8531 - recall: 0.8816 - val_accuracy: 0.7829 - val_f1_score: 0.7791 - val_loss: 0.5389 - val_precision: 0.7603 - val_recall: 0.7988 - learning_rate: 1.0000e-05
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8666 - f1_score: 0.8696 - loss: 0.3747 - precision: 0.8565 - recall: 0.8832
# Epoch 31: val_loss did not improve from 0.53826
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8666 - f1_score: 0.8696 - loss: 0.3747 - precision: 0.8565 - recall: 0.8832 - val_accuracy: 0.7836 - val_f1_score: 0.7793 - val_loss: 0.5386 - val_precision: 0.7621 - val_recall: 0.7973 - learning_rate: 1.0000e-05
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8705 - f1_score: 0.8734 - loss: 0.3697 - precision: 0.8648 - recall: 0.8822
# Epoch 32: val_loss improved from 0.53826 to 0.53790, saving model to /kaggle/working/mymodels/fold_1_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 204ms/step - accuracy: 0.8705 - f1_score: 0.8734 - loss: 0.3697 - precision: 0.8648 - recall: 0.8822 - val_accuracy: 0.7800 - val_f1_score: 0.7765 - val_loss: 0.5379 - val_precision: 0.7567 - val_recall: 0.7973 - learning_rate: 1.0000e-05
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8682 - f1_score: 0.8713 - loss: 0.3680 - precision: 0.8606 - recall: 0.8827
# Epoch 33: val_loss improved from 0.53790 to 0.53769, saving model to /kaggle/working/mymodels/fold_1_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.8682 - f1_score: 0.8713 - loss: 0.3680 - precision: 0.8606 - recall: 0.8827 - val_accuracy: 0.7829 - val_f1_score: 0.7787 - val_loss: 0.5377 - val_precision: 0.7610 - val_recall: 0.7973 - learning_rate: 1.0000e-05
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8752 - f1_score: 0.8771 - loss: 0.3620 - precision: 0.8596 - recall: 0.8957
# Epoch 34: val_loss did not improve from 0.53769
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.8752 - f1_score: 0.8772 - loss: 0.3619 - precision: 0.8597 - recall: 0.8957 - val_accuracy: 0.7843 - val_f1_score: 0.7805 - val_loss: 0.5394 - val_precision: 0.7617 - val_recall: 0.8003 - learning_rate: 1.0000e-05
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8743 - f1_score: 0.8763 - loss: 0.3631 - precision: 0.8680 - recall: 0.8849
# Epoch 35: val_loss did not improve from 0.53769
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.8743 - f1_score: 0.8763 - loss: 0.3631 - precision: 0.8680 - recall: 0.8849 - val_accuracy: 0.7821 - val_f1_score: 0.7782 - val_loss: 0.5396 - val_precision: 0.7599 - val_recall: 0.7973 - learning_rate: 1.0000e-05
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8686 - f1_score: 0.8712 - loss: 0.3717 - precision: 0.8658 - recall: 0.8768
# Epoch 36: val_loss did not improve from 0.53769
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8686 - f1_score: 0.8712 - loss: 0.3717 - precision: 0.8658 - recall: 0.8768 - val_accuracy: 0.7864 - val_f1_score: 0.7813 - val_loss: 0.5398 - val_precision: 0.7672 - val_recall: 0.7958 - learning_rate: 1.0000e-05
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8769 - f1_score: 0.8783 - loss: 0.3517 - precision: 0.8760 - recall: 0.8812
# Epoch 37: val_loss did not improve from 0.53769
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 35s 199ms/step - accuracy: 0.8769 - f1_score: 0.8783 - loss: 0.3518 - precision: 0.8760 - recall: 0.8812 - val_accuracy: 0.7821 - val_f1_score: 0.7775 - val_loss: 0.5405 - val_precision: 0.7614 - val_recall: 0.7943 - learning_rate: 1.0000e-05
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8757 - f1_score: 0.8773 - loss: 0.3596 - precision: 0.8717 - recall: 0.8831
# Epoch 38: val_loss did not improve from 0.53769
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8757 - f1_score: 0.8773 - loss: 0.3596 - precision: 0.8717 - recall: 0.8831 - val_accuracy: 0.7829 - val_f1_score: 0.7784 - val_loss: 0.5405 - val_precision: 0.7618 - val_recall: 0.7958 - learning_rate: 1.0000e-05
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8753 - f1_score: 0.8769 - loss: 0.3528 - precision: 0.8639 - recall: 0.8903
# Epoch 39: val_loss did not improve from 0.53769
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8753 - f1_score: 0.8769 - loss: 0.3528 - precision: 0.8640 - recall: 0.8903 - val_accuracy: 0.7829 - val_f1_score: 0.7781 - val_loss: 0.5400 - val_precision: 0.7625 - val_recall: 0.7943 - learning_rate: 1.0000e-05
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8858 - f1_score: 0.8872 - loss: 0.3444 - precision: 0.8829 - recall: 0.8917
# Epoch 40: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 40: val_loss did not improve from 0.53769
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 199ms/step - accuracy: 0.8858 - f1_score: 0.8872 - loss: 0.3445 - precision: 0.8829 - recall: 0.8917 - val_accuracy: 0.7836 - val_f1_score: 0.7783 - val_loss: 0.5405 - val_precision: 0.7644 - val_recall: 0.7928 - learning_rate: 1.0000e-05
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8787 - f1_score: 0.8806 - loss: 0.3568 - precision: 0.8660 - recall: 0.8959
# Epoch 41: val_loss did not improve from 0.53769
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8787 - f1_score: 0.8806 - loss: 0.3568 - precision: 0.8661 - recall: 0.8959 - val_accuracy: 0.7836 - val_f1_score: 0.7780 - val_loss: 0.5403 - val_precision: 0.7651 - val_recall: 0.7914 - learning_rate: 5.0000e-06
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8752 - f1_score: 0.8772 - loss: 0.3560 - precision: 0.8687 - recall: 0.8859
# Epoch 42: val_loss did not improve from 0.53769
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.8752 - f1_score: 0.8772 - loss: 0.3559 - precision: 0.8688 - recall: 0.8859 - val_accuracy: 0.7836 - val_f1_score: 0.7783 - val_loss: 0.5403 - val_precision: 0.7644 - val_recall: 0.7928 - learning_rate: 5.0000e-06
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8825 - f1_score: 0.8840 - loss: 0.3533 - precision: 0.8763 - recall: 0.8920
# Epoch 43: val_loss did not improve from 0.53769
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.8825 - f1_score: 0.8840 - loss: 0.3533 - precision: 0.8762 - recall: 0.8920 - val_accuracy: 0.7829 - val_f1_score: 0.7775 - val_loss: 0.5408 - val_precision: 0.7640 - val_recall: 0.7914 - learning_rate: 5.0000e-06
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8677 - f1_score: 0.8700 - loss: 0.3457 - precision: 0.8531 - recall: 0.8877
# Epoch 44: val_loss did not improve from 0.53769
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.8678 - f1_score: 0.8700 - loss: 0.3457 - precision: 0.8532 - recall: 0.8877 - val_accuracy: 0.7843 - val_f1_score: 0.7786 - val_loss: 0.5398 - val_precision: 0.7662 - val_recall: 0.7914 - learning_rate: 5.0000e-06
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8784 - f1_score: 0.8822 - loss: 0.3502 - precision: 0.8763 - recall: 0.8885
# Epoch 45: val_loss did not improve from 0.53769
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8785 - f1_score: 0.8823 - loss: 0.3502 - precision: 0.8763 - recall: 0.8885 - val_accuracy: 0.7821 - val_f1_score: 0.7772 - val_loss: 0.5416 - val_precision: 0.7622 - val_recall: 0.7928 - learning_rate: 5.0000e-06
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.8772 - f1_score: 0.8801 - loss: 0.3517 - precision: 0.8700 - recall: 0.8906
# Epoch 46: val_loss did not improve from 0.53769
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 35s 199ms/step - accuracy: 0.8772 - f1_score: 0.8801 - loss: 0.3517 - precision: 0.8700 - recall: 0.8906 - val_accuracy: 0.7821 - val_f1_score: 0.7782 - val_loss: 0.5423 - val_precision: 0.7599 - val_recall: 0.7973 - learning_rate: 5.0000e-06
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8920 - f1_score: 0.8938 - loss: 0.3385 - precision: 0.8878 - recall: 0.9000
# Epoch 47: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 47: val_loss did not improve from 0.53769
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8920 - f1_score: 0.8937 - loss: 0.3386 - precision: 0.8877 - recall: 0.8999 - val_accuracy: 0.7829 - val_f1_score: 0.7781 - val_loss: 0.5417 - val_precision: 0.7625 - val_recall: 0.7943 - learning_rate: 5.0000e-06
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8861 - f1_score: 0.8890 - loss: 0.3300 - precision: 0.8742 - recall: 0.9044
# Epoch 48: val_loss did not improve from 0.53769
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8861 - f1_score: 0.8890 - loss: 0.3301 - precision: 0.8743 - recall: 0.9044 - val_accuracy: 0.7829 - val_f1_score: 0.7784 - val_loss: 0.5420 - val_precision: 0.7618 - val_recall: 0.7958 - learning_rate: 2.5000e-06
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 33.
#
#  Loading best weights for Fold 1 for evaluation.
#
#  Evaluation for Fold 1
# Collecting predictions...
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.77      0.79       729
#          1.0       0.76      0.80      0.78       671
#
#     accuracy                           0.78      1400
#    macro avg       0.78      0.78      0.78      1400
# weighted avg       0.78      0.78      0.78      1400
#
#
#  Confusion Matrix:
#  Finished Fold 1
#
#
#
#  Starting Fold 2/5
#
# --- Fold 2: Phase 1 ---
# Epoch 1/20
#     175/Unknown 42s 172ms/step - accuracy: 0.6266 - f1_score: 0.6310 - loss: 0.8254 - precision: 0.6225 - recall: 0.6399
# Epoch 1: val_loss improved from inf to 0.63992, saving model to /kaggle/working/mymodels/fold_2_phase1_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 55s 248ms/step - accuracy: 0.6267 - f1_score: 0.6311 - loss: 0.8250 - precision: 0.6227 - recall: 0.6400 - val_accuracy: 0.6929 - val_f1_score: 0.6972 - val_loss: 0.6399 - val_precision: 0.7051 - val_recall: 0.6894 - learning_rate: 0.0010
# Epoch 2/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7062 - f1_score: 0.7068 - loss: 0.6406 - precision: 0.7048 - recall: 0.7091
# Epoch 2: val_loss improved from 0.63992 to 0.60874, saving model to /kaggle/working/mymodels/fold_2_phase1_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.7062 - f1_score: 0.7068 - loss: 0.6406 - precision: 0.7048 - recall: 0.7091 - val_accuracy: 0.7193 - val_f1_score: 0.7482 - val_loss: 0.6087 - val_precision: 0.6928 - val_recall: 0.8134 - learning_rate: 0.0010
# Epoch 3/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.7394 - f1_score: 0.7403 - loss: 0.5960 - precision: 0.7327 - recall: 0.7482
# Epoch 3: val_loss did not improve from 0.60874
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.7393 - f1_score: 0.7403 - loss: 0.5960 - precision: 0.7327 - recall: 0.7482 - val_accuracy: 0.7314 - val_f1_score: 0.7673 - val_loss: 0.6165 - val_precision: 0.6904 - val_recall: 0.8635 - learning_rate: 0.0010
# Epoch 4/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.7481 - f1_score: 0.7495 - loss: 0.5648 - precision: 0.7464 - recall: 0.7531
# Epoch 4: val_loss improved from 0.60874 to 0.58157, saving model to /kaggle/working/mymodels/fold_2_phase1_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.7481 - f1_score: 0.7495 - loss: 0.5649 - precision: 0.7464 - recall: 0.7531 - val_accuracy: 0.7457 - val_f1_score: 0.7601 - val_loss: 0.5816 - val_precision: 0.7363 - val_recall: 0.7855 - learning_rate: 0.0010
# Epoch 5/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.7721 - f1_score: 0.7732 - loss: 0.5440 - precision: 0.7608 - recall: 0.7862
# Epoch 5: val_loss did not improve from 0.58157
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.7720 - f1_score: 0.7732 - loss: 0.5440 - precision: 0.7608 - recall: 0.7862 - val_accuracy: 0.7336 - val_f1_score: 0.7702 - val_loss: 0.6092 - val_precision: 0.6906 - val_recall: 0.8705 - learning_rate: 0.0010
# Epoch 6/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.7863 - f1_score: 0.7885 - loss: 0.5144 - precision: 0.7730 - recall: 0.8056
# Epoch 6: val_loss improved from 0.58157 to 0.58120, saving model to /kaggle/working/mymodels/fold_2_phase1_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 204ms/step - accuracy: 0.7862 - f1_score: 0.7884 - loss: 0.5145 - precision: 0.7730 - recall: 0.8056 - val_accuracy: 0.7557 - val_f1_score: 0.7708 - val_loss: 0.5812 - val_precision: 0.7429 - val_recall: 0.8008 - learning_rate: 0.0010
# Epoch 7/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.7857 - f1_score: 0.7875 - loss: 0.5170 - precision: 0.7769 - recall: 0.7986
# Epoch 7: val_loss did not improve from 0.58120
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.7857 - f1_score: 0.7875 - loss: 0.5171 - precision: 0.7769 - recall: 0.7985 - val_accuracy: 0.7457 - val_f1_score: 0.7562 - val_loss: 0.5963 - val_precision: 0.7439 - val_recall: 0.7688 - learning_rate: 0.0010
# Epoch 8/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.7869 - f1_score: 0.7891 - loss: 0.5146 - precision: 0.7859 - recall: 0.7926
# Epoch 8: val_loss did not improve from 0.58120
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.7869 - f1_score: 0.7891 - loss: 0.5145 - precision: 0.7859 - recall: 0.7926 - val_accuracy: 0.7564 - val_f1_score: 0.7816 - val_loss: 0.5872 - val_precision: 0.7236 - val_recall: 0.8496 - learning_rate: 0.0010
# Epoch 9/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8049 - f1_score: 0.8088 - loss: 0.4945 - precision: 0.7983 - recall: 0.8200
# Epoch 9: val_loss did not improve from 0.58120
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8049 - f1_score: 0.8088 - loss: 0.4945 - precision: 0.7983 - recall: 0.8200 - val_accuracy: 0.7464 - val_f1_score: 0.7813 - val_loss: 0.6075 - val_precision: 0.7006 - val_recall: 0.8830 - learning_rate: 0.0010
# Epoch 10/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8122 - f1_score: 0.8139 - loss: 0.4806 - precision: 0.8097 - recall: 0.8184
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 10: val_loss did not improve from 0.58120
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8122 - f1_score: 0.8139 - loss: 0.4806 - precision: 0.8097 - recall: 0.8183 - val_accuracy: 0.7500 - val_f1_score: 0.7721 - val_loss: 0.6040 - val_precision: 0.7249 - val_recall: 0.8259 - learning_rate: 0.0010
# Epoch 11/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8070 - f1_score: 0.8051 - loss: 0.4768 - precision: 0.7932 - recall: 0.8185
# Epoch 11: val_loss improved from 0.58120 to 0.55743, saving model to /kaggle/working/mymodels/fold_2_phase1_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.8070 - f1_score: 0.8051 - loss: 0.4768 - precision: 0.7933 - recall: 0.8185 - val_accuracy: 0.7643 - val_f1_score: 0.7794 - val_loss: 0.5574 - val_precision: 0.7494 - val_recall: 0.8120 - learning_rate: 5.0000e-04
# Epoch 12/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8326 - f1_score: 0.8342 - loss: 0.4297 - precision: 0.8252 - recall: 0.8436
# Epoch 12: val_loss did not improve from 0.55743
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8326 - f1_score: 0.8342 - loss: 0.4297 - precision: 0.8252 - recall: 0.8436 - val_accuracy: 0.7621 - val_f1_score: 0.7575 - val_loss: 0.6011 - val_precision: 0.7939 - val_recall: 0.7242 - learning_rate: 5.0000e-04
# Epoch 13/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8404 - f1_score: 0.8407 - loss: 0.4310 - precision: 0.8406 - recall: 0.8411
# Epoch 13: val_loss did not improve from 0.55743
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8404 - f1_score: 0.8407 - loss: 0.4309 - precision: 0.8405 - recall: 0.8412 - val_accuracy: 0.7650 - val_f1_score: 0.7785 - val_loss: 0.5794 - val_precision: 0.7536 - val_recall: 0.8050 - learning_rate: 5.0000e-04
# Epoch 14/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8406 - f1_score: 0.8397 - loss: 0.4176 - precision: 0.8381 - recall: 0.8414
# Epoch 14: val_loss did not improve from 0.55743
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8406 - f1_score: 0.8397 - loss: 0.4177 - precision: 0.8381 - recall: 0.8414 - val_accuracy: 0.7557 - val_f1_score: 0.7595 - val_loss: 0.5930 - val_precision: 0.7670 - val_recall: 0.7521 - learning_rate: 5.0000e-04
# Epoch 15/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8549 - f1_score: 0.8549 - loss: 0.4043 - precision: 0.8493 - recall: 0.8606
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 15: val_loss did not improve from 0.55743
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.8549 - f1_score: 0.8548 - loss: 0.4044 - precision: 0.8493 - recall: 0.8606 - val_accuracy: 0.7493 - val_f1_score: 0.7819 - val_loss: 0.6434 - val_precision: 0.7059 - val_recall: 0.8760 - learning_rate: 5.0000e-04
# Epoch 16/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8516 - f1_score: 0.8513 - loss: 0.4023 - precision: 0.8470 - recall: 0.8561
# Epoch 16: val_loss did not improve from 0.55743
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8516 - f1_score: 0.8513 - loss: 0.4022 - precision: 0.8470 - recall: 0.8562 - val_accuracy: 0.7736 - val_f1_score: 0.7827 - val_loss: 0.5792 - val_precision: 0.7706 - val_recall: 0.7953 - learning_rate: 2.5000e-04
# Epoch 17/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8660 - f1_score: 0.8663 - loss: 0.3688 - precision: 0.8622 - recall: 0.8705
# Epoch 17: val_loss did not improve from 0.55743
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.8660 - f1_score: 0.8663 - loss: 0.3688 - precision: 0.8622 - recall: 0.8705 - val_accuracy: 0.7621 - val_f1_score: 0.7711 - val_loss: 0.5890 - val_precision: 0.7612 - val_recall: 0.7813 - learning_rate: 2.5000e-04
# Epoch 18/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8791 - f1_score: 0.8817 - loss: 0.3560 - precision: 0.8714 - recall: 0.8930
# Epoch 18: val_loss did not improve from 0.55743
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.8791 - f1_score: 0.8817 - loss: 0.3560 - precision: 0.8714 - recall: 0.8930 - val_accuracy: 0.7664 - val_f1_score: 0.7827 - val_loss: 0.5945 - val_precision: 0.7484 - val_recall: 0.8203 - learning_rate: 2.5000e-04
# Epoch 19/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8788 - f1_score: 0.8786 - loss: 0.3506 - precision: 0.8662 - recall: 0.8916
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 19: val_loss did not improve from 0.55743
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8788 - f1_score: 0.8786 - loss: 0.3505 - precision: 0.8662 - recall: 0.8915 - val_accuracy: 0.7571 - val_f1_score: 0.7763 - val_loss: 0.5986 - val_precision: 0.7357 - val_recall: 0.8217 - learning_rate: 2.5000e-04
# Epoch 20/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.8734 - f1_score: 0.8748 - loss: 0.3430 - precision: 0.8602 - recall: 0.8910
# Epoch 20: val_loss did not improve from 0.55743
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 35s 198ms/step - accuracy: 0.8734 - f1_score: 0.8748 - loss: 0.3430 - precision: 0.8603 - recall: 0.8910 - val_accuracy: 0.7707 - val_f1_score: 0.7815 - val_loss: 0.5901 - val_precision: 0.7643 - val_recall: 0.7994 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 11.
# Loading best phase 1 weights for Fold 2.
#
#  Fold 2: Phase 2
# Epoch 21/50
#     175/Unknown 41s 165ms/step - accuracy: 0.8350 - f1_score: 0.8369 - loss: 0.4382 - precision: 0.8238 - recall: 0.8507
# Epoch 21: val_loss improved from inf to 0.55694, saving model to /kaggle/working/mymodels/fold_2_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 54s 243ms/step - accuracy: 0.8350 - f1_score: 0.8369 - loss: 0.4381 - precision: 0.8238 - recall: 0.8507 - val_accuracy: 0.7657 - val_f1_score: 0.7781 - val_loss: 0.5569 - val_precision: 0.7566 - val_recall: 0.8008 - learning_rate: 1.0000e-05
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8347 - f1_score: 0.8359 - loss: 0.4305 - precision: 0.8265 - recall: 0.8458
# Epoch 22: val_loss improved from 0.55694 to 0.55545, saving model to /kaggle/working/mymodels/fold_2_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 205ms/step - accuracy: 0.8347 - f1_score: 0.8360 - loss: 0.4304 - precision: 0.8265 - recall: 0.8458 - val_accuracy: 0.7671 - val_f1_score: 0.7782 - val_loss: 0.5554 - val_precision: 0.7606 - val_recall: 0.7967 - learning_rate: 1.0000e-05
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8403 - f1_score: 0.8402 - loss: 0.4283 - precision: 0.8335 - recall: 0.8473
# Epoch 23: val_loss improved from 0.55545 to 0.55447, saving model to /kaggle/working/mymodels/fold_2_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.8404 - f1_score: 0.8402 - loss: 0.4283 - precision: 0.8335 - recall: 0.8473 - val_accuracy: 0.7671 - val_f1_score: 0.7800 - val_loss: 0.5545 - val_precision: 0.7565 - val_recall: 0.8050 - learning_rate: 1.0000e-05
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8468 - f1_score: 0.8477 - loss: 0.4215 - precision: 0.8406 - recall: 0.8550
# Epoch 24: val_loss improved from 0.55447 to 0.55318, saving model to /kaggle/working/mymodels/fold_2_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.8468 - f1_score: 0.8477 - loss: 0.4215 - precision: 0.8406 - recall: 0.8550 - val_accuracy: 0.7657 - val_f1_score: 0.7784 - val_loss: 0.5532 - val_precision: 0.7559 - val_recall: 0.8022 - learning_rate: 1.0000e-05
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8387 - f1_score: 0.8417 - loss: 0.4250 - precision: 0.8259 - recall: 0.8584
# Epoch 25: val_loss improved from 0.55318 to 0.55315, saving model to /kaggle/working/mymodels/fold_2_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.8387 - f1_score: 0.8417 - loss: 0.4250 - precision: 0.8259 - recall: 0.8584 - val_accuracy: 0.7686 - val_f1_score: 0.7814 - val_loss: 0.5531 - val_precision: 0.7579 - val_recall: 0.8064 - learning_rate: 1.0000e-05
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8460 - f1_score: 0.8465 - loss: 0.4098 - precision: 0.8391 - recall: 0.8544
# Epoch 26: val_loss improved from 0.55315 to 0.55254, saving model to /kaggle/working/mymodels/fold_2_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.8460 - f1_score: 0.8465 - loss: 0.4098 - precision: 0.8391 - recall: 0.8544 - val_accuracy: 0.7707 - val_f1_score: 0.7853 - val_loss: 0.5525 - val_precision: 0.7555 - val_recall: 0.8175 - learning_rate: 1.0000e-05
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8508 - f1_score: 0.8529 - loss: 0.4050 - precision: 0.8487 - recall: 0.8574
# Epoch 27: val_loss improved from 0.55254 to 0.55168, saving model to /kaggle/working/mymodels/fold_2_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.8508 - f1_score: 0.8529 - loss: 0.4050 - precision: 0.8487 - recall: 0.8574 - val_accuracy: 0.7714 - val_f1_score: 0.7847 - val_loss: 0.5517 - val_precision: 0.7591 - val_recall: 0.8120 - learning_rate: 1.0000e-05
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8398 - f1_score: 0.8420 - loss: 0.4158 - precision: 0.8304 - recall: 0.8546
# Epoch 28: val_loss improved from 0.55168 to 0.55105, saving model to /kaggle/working/mymodels/fold_2_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 204ms/step - accuracy: 0.8399 - f1_score: 0.8420 - loss: 0.4157 - precision: 0.8304 - recall: 0.8546 - val_accuracy: 0.7721 - val_f1_score: 0.7849 - val_loss: 0.5510 - val_precision: 0.7608 - val_recall: 0.8106 - learning_rate: 1.0000e-05
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8538 - f1_score: 0.8532 - loss: 0.3956 - precision: 0.8465 - recall: 0.8602
# Epoch 29: val_loss did not improve from 0.55105
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8538 - f1_score: 0.8532 - loss: 0.3956 - precision: 0.8465 - recall: 0.8601 - val_accuracy: 0.7721 - val_f1_score: 0.7849 - val_loss: 0.5515 - val_precision: 0.7608 - val_recall: 0.8106 - learning_rate: 1.0000e-05
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8406 - f1_score: 0.8407 - loss: 0.4078 - precision: 0.8317 - recall: 0.8501
# Epoch 30: val_loss did not improve from 0.55105
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.8407 - f1_score: 0.8407 - loss: 0.4077 - precision: 0.8317 - recall: 0.8501 - val_accuracy: 0.7729 - val_f1_score: 0.7860 - val_loss: 0.5512 - val_precision: 0.7604 - val_recall: 0.8134 - learning_rate: 1.0000e-05
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8583 - f1_score: 0.8592 - loss: 0.4005 - precision: 0.8545 - recall: 0.8642
# Epoch 31: val_loss improved from 0.55105 to 0.55029, saving model to /kaggle/working/mymodels/fold_2_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 206ms/step - accuracy: 0.8583 - f1_score: 0.8591 - loss: 0.4005 - precision: 0.8544 - recall: 0.8642 - val_accuracy: 0.7743 - val_f1_score: 0.7871 - val_loss: 0.5503 - val_precision: 0.7624 - val_recall: 0.8134 - learning_rate: 1.0000e-05
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8490 - f1_score: 0.8486 - loss: 0.3927 - precision: 0.8500 - recall: 0.8478
# Epoch 32: val_loss improved from 0.55029 to 0.55002, saving model to /kaggle/working/mymodels/fold_2_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.8490 - f1_score: 0.8486 - loss: 0.3927 - precision: 0.8500 - recall: 0.8478 - val_accuracy: 0.7736 - val_f1_score: 0.7868 - val_loss: 0.5500 - val_precision: 0.7607 - val_recall: 0.8148 - learning_rate: 1.0000e-05
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8492 - f1_score: 0.8490 - loss: 0.4002 - precision: 0.8385 - recall: 0.8599
# Epoch 33: val_loss did not improve from 0.55002
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.8491 - f1_score: 0.8490 - loss: 0.4001 - precision: 0.8385 - recall: 0.8598 - val_accuracy: 0.7714 - val_f1_score: 0.7841 - val_loss: 0.5503 - val_precision: 0.7605 - val_recall: 0.8092 - learning_rate: 1.0000e-05
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8458 - f1_score: 0.8467 - loss: 0.4070 - precision: 0.8398 - recall: 0.8540
# Epoch 34: val_loss improved from 0.55002 to 0.54995, saving model to /kaggle/working/mymodels/fold_2_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.8458 - f1_score: 0.8467 - loss: 0.4070 - precision: 0.8398 - recall: 0.8540 - val_accuracy: 0.7736 - val_f1_score: 0.7862 - val_loss: 0.5499 - val_precision: 0.7621 - val_recall: 0.8120 - learning_rate: 1.0000e-05
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8584 - f1_score: 0.8597 - loss: 0.3883 - precision: 0.8499 - recall: 0.8698
# Epoch 35: val_loss improved from 0.54995 to 0.54990, saving model to /kaggle/working/mymodels/fold_2_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 203ms/step - accuracy: 0.8583 - f1_score: 0.8596 - loss: 0.3883 - precision: 0.8499 - recall: 0.8698 - val_accuracy: 0.7729 - val_f1_score: 0.7863 - val_loss: 0.5499 - val_precision: 0.7597 - val_recall: 0.8148 - learning_rate: 1.0000e-05
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8549 - f1_score: 0.8567 - loss: 0.3916 - precision: 0.8450 - recall: 0.8689
# Epoch 36: val_loss did not improve from 0.54990
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8549 - f1_score: 0.8567 - loss: 0.3915 - precision: 0.8450 - recall: 0.8688 - val_accuracy: 0.7700 - val_f1_score: 0.7827 - val_loss: 0.5502 - val_precision: 0.7592 - val_recall: 0.8078 - learning_rate: 1.0000e-05
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8585 - f1_score: 0.8587 - loss: 0.3882 - precision: 0.8472 - recall: 0.8706
# Epoch 37: val_loss improved from 0.54990 to 0.54989, saving model to /kaggle/working/mymodels/fold_2_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.8585 - f1_score: 0.8587 - loss: 0.3882 - precision: 0.8472 - recall: 0.8705 - val_accuracy: 0.7736 - val_f1_score: 0.7857 - val_loss: 0.5499 - val_precision: 0.7635 - val_recall: 0.8092 - learning_rate: 1.0000e-05
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8504 - f1_score: 0.8494 - loss: 0.3892 - precision: 0.8382 - recall: 0.8617
# Epoch 38: val_loss did not improve from 0.54989
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.8504 - f1_score: 0.8495 - loss: 0.3892 - precision: 0.8383 - recall: 0.8617 - val_accuracy: 0.7714 - val_f1_score: 0.7838 - val_loss: 0.5506 - val_precision: 0.7612 - val_recall: 0.8078 - learning_rate: 1.0000e-05
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8516 - f1_score: 0.8524 - loss: 0.3888 - precision: 0.8491 - recall: 0.8560
# Epoch 39: val_loss did not improve from 0.54989
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8517 - f1_score: 0.8525 - loss: 0.3888 - precision: 0.8491 - recall: 0.8560 - val_accuracy: 0.7729 - val_f1_score: 0.7857 - val_loss: 0.5511 - val_precision: 0.7611 - val_recall: 0.8120 - learning_rate: 1.0000e-05
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8563 - f1_score: 0.8575 - loss: 0.3826 - precision: 0.8460 - recall: 0.8695
# Epoch 40: val_loss did not improve from 0.54989
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.8563 - f1_score: 0.8575 - loss: 0.3826 - precision: 0.8460 - recall: 0.8695 - val_accuracy: 0.7743 - val_f1_score: 0.7865 - val_loss: 0.5511 - val_precision: 0.7638 - val_recall: 0.8106 - learning_rate: 1.0000e-05
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8573 - f1_score: 0.8563 - loss: 0.3974 - precision: 0.8563 - recall: 0.8564
# Epoch 41: val_loss did not improve from 0.54989
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8573 - f1_score: 0.8563 - loss: 0.3974 - precision: 0.8563 - recall: 0.8565 - val_accuracy: 0.7721 - val_f1_score: 0.7846 - val_loss: 0.5511 - val_precision: 0.7615 - val_recall: 0.8092 - learning_rate: 1.0000e-05
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8553 - f1_score: 0.8571 - loss: 0.3889 - precision: 0.8589 - recall: 0.8557
# Epoch 42: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 42: val_loss did not improve from 0.54989
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8553 - f1_score: 0.8571 - loss: 0.3889 - precision: 0.8588 - recall: 0.8557 - val_accuracy: 0.7714 - val_f1_score: 0.7847 - val_loss: 0.5502 - val_precision: 0.7591 - val_recall: 0.8120 - learning_rate: 1.0000e-05
# Epoch 43/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8485 - f1_score: 0.8475 - loss: 0.3884 - precision: 0.8282 - recall: 0.8685
# Epoch 43: val_loss did not improve from 0.54989
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 199ms/step - accuracy: 0.8486 - f1_score: 0.8476 - loss: 0.3883 - precision: 0.8283 - recall: 0.8684 - val_accuracy: 0.7714 - val_f1_score: 0.7838 - val_loss: 0.5505 - val_precision: 0.7612 - val_recall: 0.8078 - learning_rate: 5.0000e-06
# Epoch 44/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8506 - f1_score: 0.8499 - loss: 0.3779 - precision: 0.8420 - recall: 0.8580
# Epoch 44: val_loss did not improve from 0.54989
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8506 - f1_score: 0.8499 - loss: 0.3779 - precision: 0.8421 - recall: 0.8580 - val_accuracy: 0.7707 - val_f1_score: 0.7827 - val_loss: 0.5503 - val_precision: 0.7615 - val_recall: 0.8050 - learning_rate: 5.0000e-06
# Epoch 45/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8612 - f1_score: 0.8606 - loss: 0.3763 - precision: 0.8550 - recall: 0.8666
# Epoch 45: val_loss did not improve from 0.54989
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8612 - f1_score: 0.8606 - loss: 0.3763 - precision: 0.8550 - recall: 0.8666 - val_accuracy: 0.7714 - val_f1_score: 0.7838 - val_loss: 0.5511 - val_precision: 0.7612 - val_recall: 0.8078 - learning_rate: 5.0000e-06
# Epoch 46/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8572 - f1_score: 0.8579 - loss: 0.3828 - precision: 0.8486 - recall: 0.8676
# Epoch 46: val_loss did not improve from 0.54989
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 35s 198ms/step - accuracy: 0.8573 - f1_score: 0.8579 - loss: 0.3828 - precision: 0.8487 - recall: 0.8676 - val_accuracy: 0.7721 - val_f1_score: 0.7852 - val_loss: 0.5511 - val_precision: 0.7601 - val_recall: 0.8120 - learning_rate: 5.0000e-06
# Epoch 47/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8641 - f1_score: 0.8637 - loss: 0.3707 - precision: 0.8582 - recall: 0.8693
# Epoch 47: val_loss did not improve from 0.54989
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8641 - f1_score: 0.8636 - loss: 0.3707 - precision: 0.8582 - recall: 0.8693 - val_accuracy: 0.7729 - val_f1_score: 0.7851 - val_loss: 0.5513 - val_precision: 0.7625 - val_recall: 0.8092 - learning_rate: 5.0000e-06
# Epoch 48/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8623 - f1_score: 0.8633 - loss: 0.3699 - precision: 0.8532 - recall: 0.8739
# ...
#
# Epoch 13: val_loss did not improve from 0.54864
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 35s 199ms/step - accuracy: 0.8141 - f1_score: 0.8168 - loss: 0.4808 - precision: 0.8007 - recall: 0.8338 - val_accuracy: 0.7686 - val_f1_score: 0.7725 - val_loss: 0.5590 - val_precision: 0.7493 - val_recall: 0.7971 - learning_rate: 0.0010
# Epoch 14/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8338 - f1_score: 0.8359 - loss: 0.4473 - precision: 0.8221 - recall: 0.8504
# Epoch 14: val_loss improved from 0.54864 to 0.54097, saving model to /kaggle/working/mymodels/fold_5_phase1_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.8338 - f1_score: 0.8359 - loss: 0.4473 - precision: 0.8222 - recall: 0.8504 - val_accuracy: 0.7814 - val_f1_score: 0.7821 - val_loss: 0.5410 - val_precision: 0.7689 - val_recall: 0.7957 - learning_rate: 5.0000e-04
# Epoch 15/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8399 - f1_score: 0.8416 - loss: 0.4319 - precision: 0.8286 - recall: 0.8554
# Epoch 15: val_loss did not improve from 0.54097
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8399 - f1_score: 0.8416 - loss: 0.4319 - precision: 0.8287 - recall: 0.8554 - val_accuracy: 0.7921 - val_f1_score: 0.7923 - val_loss: 0.5432 - val_precision: 0.7806 - val_recall: 0.8043 - learning_rate: 5.0000e-04
# Epoch 16/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8508 - f1_score: 0.8502 - loss: 0.4102 - precision: 0.8398 - recall: 0.8621
# Epoch 16: val_loss did not improve from 0.54097
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.8508 - f1_score: 0.8502 - loss: 0.4102 - precision: 0.8398 - recall: 0.8620 - val_accuracy: 0.7750 - val_f1_score: 0.7805 - val_loss: 0.5722 - val_precision: 0.7517 - val_recall: 0.8116 - learning_rate: 5.0000e-04
# Epoch 17/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8569 - f1_score: 0.8588 - loss: 0.4003 - precision: 0.8463 - recall: 0.8719
# Epoch 17: val_loss did not improve from 0.54097
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8569 - f1_score: 0.8588 - loss: 0.4003 - precision: 0.8464 - recall: 0.8719 - val_accuracy: 0.7664 - val_f1_score: 0.7728 - val_loss: 0.5671 - val_precision: 0.7423 - val_recall: 0.8058 - learning_rate: 5.0000e-04
# Epoch 18/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8460 - f1_score: 0.8475 - loss: 0.3987 - precision: 0.8447 - recall: 0.8505
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 18: val_loss did not improve from 0.54097
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8461 - f1_score: 0.8475 - loss: 0.3987 - precision: 0.8447 - recall: 0.8505 - val_accuracy: 0.7836 - val_f1_score: 0.7859 - val_loss: 0.5652 - val_precision: 0.7669 - val_recall: 0.8058 - learning_rate: 5.0000e-04
# Epoch 19/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8736 - f1_score: 0.8759 - loss: 0.3708 - precision: 0.8640 - recall: 0.8883
# Epoch 19: val_loss did not improve from 0.54097
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.8736 - f1_score: 0.8759 - loss: 0.3707 - precision: 0.8640 - recall: 0.8883 - val_accuracy: 0.7843 - val_f1_score: 0.7897 - val_loss: 0.5656 - val_precision: 0.7601 - val_recall: 0.8217 - learning_rate: 2.5000e-04
# Epoch 20/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8784 - f1_score: 0.8799 - loss: 0.3483 - precision: 0.8720 - recall: 0.8880
# Epoch 20: val_loss did not improve from 0.54097
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8784 - f1_score: 0.8798 - loss: 0.3484 - precision: 0.8719 - recall: 0.8880 - val_accuracy: 0.7764 - val_f1_score: 0.7889 - val_loss: 0.5966 - val_precision: 0.7377 - val_recall: 0.8478 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 14.
# Loading best phase 1 weights for Fold 5.
#
#  Fold 5: Phase 2
# Epoch 21/50
#     175/Unknown 41s 163ms/step - accuracy: 0.8453 - f1_score: 0.8473 - loss: 0.4162 - precision: 0.8340 - recall: 0.8613
# Epoch 21: val_loss improved from inf to 0.53810, saving model to /kaggle/working/mymodels/fold_5_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 54s 241ms/step - accuracy: 0.8453 - f1_score: 0.8474 - loss: 0.4162 - precision: 0.8340 - recall: 0.8613 - val_accuracy: 0.7893 - val_f1_score: 0.7912 - val_loss: 0.5381 - val_precision: 0.7732 - val_recall: 0.8101 - learning_rate: 1.0000e-05
# Epoch 22/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8553 - f1_score: 0.8570 - loss: 0.4095 - precision: 0.8395 - recall: 0.8755
# Epoch 22: val_loss improved from 0.53810 to 0.53683, saving model to /kaggle/working/mymodels/fold_5_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.8553 - f1_score: 0.8570 - loss: 0.4095 - precision: 0.8396 - recall: 0.8754 - val_accuracy: 0.7900 - val_f1_score: 0.7918 - val_loss: 0.5368 - val_precision: 0.7742 - val_recall: 0.8101 - learning_rate: 1.0000e-05
# Epoch 23/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8472 - f1_score: 0.8483 - loss: 0.4150 - precision: 0.8375 - recall: 0.8596
# Epoch 23: val_loss improved from 0.53683 to 0.53545, saving model to /kaggle/working/mymodels/fold_5_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 205ms/step - accuracy: 0.8472 - f1_score: 0.8484 - loss: 0.4150 - precision: 0.8375 - recall: 0.8596 - val_accuracy: 0.7893 - val_f1_score: 0.7918 - val_loss: 0.5355 - val_precision: 0.7717 - val_recall: 0.8130 - learning_rate: 1.0000e-05
# Epoch 24/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8517 - f1_score: 0.8536 - loss: 0.4033 - precision: 0.8396 - recall: 0.8682
# Epoch 24: val_loss improved from 0.53545 to 0.53476, saving model to /kaggle/working/mymodels/fold_5_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.8517 - f1_score: 0.8536 - loss: 0.4033 - precision: 0.8396 - recall: 0.8682 - val_accuracy: 0.7914 - val_f1_score: 0.7941 - val_loss: 0.5348 - val_precision: 0.7734 - val_recall: 0.8159 - learning_rate: 1.0000e-05
# Epoch 25/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8596 - f1_score: 0.8616 - loss: 0.4051 - precision: 0.8480 - recall: 0.8760
# Epoch 25: val_loss improved from 0.53476 to 0.53323, saving model to /kaggle/working/mymodels/fold_5_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 204ms/step - accuracy: 0.8596 - f1_score: 0.8615 - loss: 0.4050 - precision: 0.8480 - recall: 0.8759 - val_accuracy: 0.7929 - val_f1_score: 0.7949 - val_loss: 0.5332 - val_precision: 0.7762 - val_recall: 0.8145 - learning_rate: 1.0000e-05
# Epoch 26/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8483 - f1_score: 0.8481 - loss: 0.4179 - precision: 0.8287 - recall: 0.8693
# Epoch 26: val_loss improved from 0.53323 to 0.53297, saving model to /kaggle/working/mymodels/fold_5_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.8483 - f1_score: 0.8481 - loss: 0.4178 - precision: 0.8288 - recall: 0.8693 - val_accuracy: 0.7929 - val_f1_score: 0.7952 - val_loss: 0.5330 - val_precision: 0.7755 - val_recall: 0.8159 - learning_rate: 1.0000e-05
# Epoch 27/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8703 - f1_score: 0.8722 - loss: 0.3811 - precision: 0.8599 - recall: 0.8852
# Epoch 27: val_loss improved from 0.53297 to 0.53271, saving model to /kaggle/working/mymodels/fold_5_phase2_best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 207ms/step - accuracy: 0.8703 - f1_score: 0.8722 - loss: 0.3811 - precision: 0.8599 - recall: 0.8852 - val_accuracy: 0.7936 - val_f1_score: 0.7946 - val_loss: 0.5327 - val_precision: 0.7796 - val_recall: 0.8101 - learning_rate: 1.0000e-05
# Epoch 28/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8515 - f1_score: 0.8544 - loss: 0.3931 - precision: 0.8423 - recall: 0.8669
# Epoch 28: val_loss did not improve from 0.53271
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.8516 - f1_score: 0.8544 - loss: 0.3930 - precision: 0.8424 - recall: 0.8669 - val_accuracy: 0.7943 - val_f1_score: 0.7963 - val_loss: 0.5331 - val_precision: 0.7776 - val_recall: 0.8159 - learning_rate: 1.0000e-05
# Epoch 29/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8580 - f1_score: 0.8595 - loss: 0.3888 - precision: 0.8475 - recall: 0.8721
# Epoch 29: val_loss did not improve from 0.53271
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8580 - f1_score: 0.8595 - loss: 0.3888 - precision: 0.8475 - recall: 0.8721 - val_accuracy: 0.7943 - val_f1_score: 0.7969 - val_loss: 0.5336 - val_precision: 0.7761 - val_recall: 0.8188 - learning_rate: 1.0000e-05
# Epoch 30/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8605 - f1_score: 0.8617 - loss: 0.3893 - precision: 0.8428 - recall: 0.8822
# Epoch 30: val_loss did not improve from 0.53271
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.8605 - f1_score: 0.8618 - loss: 0.3893 - precision: 0.8429 - recall: 0.8822 - val_accuracy: 0.7957 - val_f1_score: 0.7977 - val_loss: 0.5337 - val_precision: 0.7790 - val_recall: 0.8174 - learning_rate: 1.0000e-05
# Epoch 31/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8763 - f1_score: 0.8766 - loss: 0.3747 - precision: 0.8642 - recall: 0.8894
# Epoch 31: val_loss did not improve from 0.53271
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8762 - f1_score: 0.8766 - loss: 0.3747 - precision: 0.8642 - recall: 0.8894 - val_accuracy: 0.7957 - val_f1_score: 0.7975 - val_loss: 0.5338 - val_precision: 0.7798 - val_recall: 0.8159 - learning_rate: 1.0000e-05
# Epoch 32/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8499 - f1_score: 0.8504 - loss: 0.3949 - precision: 0.8454 - recall: 0.8556
# Epoch 32: val_loss did not improve from 0.53271
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8499 - f1_score: 0.8505 - loss: 0.3948 - precision: 0.8454 - recall: 0.8556 - val_accuracy: 0.7950 - val_f1_score: 0.7972 - val_loss: 0.5345 - val_precision: 0.7779 - val_recall: 0.8174 - learning_rate: 1.0000e-05
# Epoch 33/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8627 - f1_score: 0.8639 - loss: 0.3849 - precision: 0.8494 - recall: 0.8790
# Epoch 33: val_loss did not improve from 0.53271
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8627 - f1_score: 0.8639 - loss: 0.3849 - precision: 0.8495 - recall: 0.8789 - val_accuracy: 0.7943 - val_f1_score: 0.7969 - val_loss: 0.5349 - val_precision: 0.7761 - val_recall: 0.8188 - learning_rate: 1.0000e-05
# Epoch 34/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8640 - f1_score: 0.8670 - loss: 0.3772 - precision: 0.8571 - recall: 0.8772
# Epoch 34: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 34: val_loss did not improve from 0.53271
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8639 - f1_score: 0.8669 - loss: 0.3771 - precision: 0.8571 - recall: 0.8772 - val_accuracy: 0.7957 - val_f1_score: 0.7983 - val_loss: 0.5354 - val_precision: 0.7775 - val_recall: 0.8203 - learning_rate: 1.0000e-05
# Epoch 35/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8644 - f1_score: 0.8656 - loss: 0.3786 - precision: 0.8587 - recall: 0.8727
# Epoch 35: val_loss did not improve from 0.53271
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8643 - f1_score: 0.8655 - loss: 0.3787 - precision: 0.8586 - recall: 0.8727 - val_accuracy: 0.7936 - val_f1_score: 0.7955 - val_loss: 0.5347 - val_precision: 0.7773 - val_recall: 0.8145 - learning_rate: 5.0000e-06
# Epoch 36/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8573 - f1_score: 0.8593 - loss: 0.3810 - precision: 0.8513 - recall: 0.8676
# Epoch 36: val_loss did not improve from 0.53271
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8573 - f1_score: 0.8593 - loss: 0.3810 - precision: 0.8513 - recall: 0.8676 - val_accuracy: 0.7943 - val_f1_score: 0.7955 - val_loss: 0.5345 - val_precision: 0.7799 - val_recall: 0.8116 - learning_rate: 5.0000e-06
# Epoch 37/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8633 - f1_score: 0.8653 - loss: 0.3768 - precision: 0.8539 - recall: 0.8776
# Epoch 37: val_loss did not improve from 0.53271
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.8633 - f1_score: 0.8654 - loss: 0.3768 - precision: 0.8539 - recall: 0.8776 - val_accuracy: 0.7936 - val_f1_score: 0.7949 - val_loss: 0.5346 - val_precision: 0.7789 - val_recall: 0.8116 - learning_rate: 5.0000e-06
# Epoch 38/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8581 - f1_score: 0.8611 - loss: 0.3800 - precision: 0.8501 - recall: 0.8725
# Epoch 38: val_loss did not improve from 0.53271
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 201ms/step - accuracy: 0.8581 - f1_score: 0.8611 - loss: 0.3800 - precision: 0.8501 - recall: 0.8725 - val_accuracy: 0.7943 - val_f1_score: 0.7960 - val_loss: 0.5350 - val_precision: 0.7784 - val_recall: 0.8145 - learning_rate: 5.0000e-06
# Epoch 39/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8623 - f1_score: 0.8667 - loss: 0.3812 - precision: 0.8527 - recall: 0.8815
# Epoch 39: val_loss did not improve from 0.53271
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8623 - f1_score: 0.8667 - loss: 0.3811 - precision: 0.8527 - recall: 0.8815 - val_accuracy: 0.7957 - val_f1_score: 0.7980 - val_loss: 0.5359 - val_precision: 0.7782 - val_recall: 0.8188 - learning_rate: 5.0000e-06
# Epoch 40/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8673 - f1_score: 0.8699 - loss: 0.3802 - precision: 0.8531 - recall: 0.8874
# Epoch 40: val_loss did not improve from 0.53271
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 200ms/step - accuracy: 0.8672 - f1_score: 0.8698 - loss: 0.3802 - precision: 0.8531 - recall: 0.8874 - val_accuracy: 0.7950 - val_f1_score: 0.7972 - val_loss: 0.5350 - val_precision: 0.7779 - val_recall: 0.8174 - learning_rate: 5.0000e-06
# Epoch 41/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8646 - f1_score: 0.8666 - loss: 0.3804 - precision: 0.8549 - recall: 0.8791
# Epoch 41: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 41: val_loss did not improve from 0.53271
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - accuracy: 0.8646 - f1_score: 0.8667 - loss: 0.3804 - precision: 0.8549 - recall: 0.8791 - val_accuracy: 0.7950 - val_f1_score: 0.7977 - val_loss: 0.5362 - val_precision: 0.7764 - val_recall: 0.8203 - learning_rate: 5.0000e-06
# Epoch 42/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8623 - f1_score: 0.8651 - loss: 0.3791 - precision: 0.8502 - recall: 0.8807
# Epoch 42: val_loss did not improve from 0.53271
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 36s 202ms/step - accuracy: 0.8623 - f1_score: 0.8652 - loss: 0.3791 - precision: 0.8503 - recall: 0.8807 - val_accuracy: 0.7936 - val_f1_score: 0.7958 - val_loss: 0.5356 - val_precision: 0.7766 - val_recall: 0.8159 - learning_rate: 2.5000e-06
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 27.
#
#  Loading best weights for Fold 5 for evaluation.
#
#  Evaluation for Fold 5
# Collecting predictions...
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.78      0.79       710
#          1.0       0.78      0.81      0.79       690
#
#     accuracy                           0.79      1400
#    macro avg       0.79      0.79      0.79      1400
# weighted avg       0.79      0.79      0.79      1400
#
#
#  Confusion Matrix:
#  Finished Fold 5
#
#
#
#  K-Fold Cross-Validation Summary
#
#  Average Performance Across Folds:
# Average Accuracy: 0.7783 ± 0.0089
# Average Precision: 0.0000 ± 0.0000
# Average Recall: 0.0000 ± 0.0000
# Average F1-Score: 0.0000 ± 0.0000
# Average Auc: 0.8587 ± 0.0060
#
#  Overall Metrics (Pooled Predictions):
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.76      0.77      3500
#          1.0       0.77      0.80      0.78      3500
#
#     accuracy                           0.78      7000
#    macro avg       0.78      0.78      0.78      7000
# weighted avg       0.78      0.78      0.78      7000
#  Project Finished

# %%
# Choose and Execute Project Mode

# Uncomment one of the lines below to run the desired mode

# main(CONFIG, mode='train') # Run K-Fold Training (if you wanna train the model)

#Or,

main(CONFIG, mode='predict_dir') # To Predict using trained model (predicting different dataset (which's not trained on) images)
# Out:
# Starting predict_dir mode
# Running directory prediction...
# Loading model from: /kaggle/working/mymodels/fold_4_phase2_best_model.keras
# Model loaded.
# Found 120 images in /kaggle/input/imagetest2/test2. Predicting...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 987ms/step
# Predictions complete.
#
#  Prediction Results
# real (32).jpg: Prob (Fake) = 0.0989, Predicted = Real
# fake (33).jpg: Prob (Fake) = 0.6259, Predicted = Fake
# fake (14).jpg: Prob (Fake) = 0.9322, Predicted = Fake
# real (42).jpg: Prob (Fake) = 0.5663, Predicted = Fake
# real (14).jpg: Prob (Fake) = 0.1432, Predicted = Real
# fake (43).jpg: Prob (Fake) = 0.8333, Predicted = Fake
# real (39).jpg: Prob (Fake) = 0.2440, Predicted = Real
# fake (26).jpg: Prob (Fake) = 0.6264, Predicted = Fake
# fake (52).jpg: Prob (Fake) = 0.6378, Predicted = Fake
# real (29).jpg: Prob (Fake) = 0.1220, Predicted = Real
# real (10).jpg: Prob (Fake) = 0.4973, Predicted = Real
# fake (13).jpg: Prob (Fake) = 0.7087, Predicted = Fake
# real (13).jpg: Prob (Fake) = 0.0910, Predicted = Real
# real (23).jpg: Prob (Fake) = 0.0125, Predicted = Real
# real (4).jpg: Prob (Fake) = 0.1078, Predicted = Real
# fake (12).jpg: Prob (Fake) = 0.9301, Predicted = Fake
# real (26).jpg: Prob (Fake) = 0.0564, Predicted = Real
# fake (54).jpg: Prob (Fake) = 0.9859, Predicted = Fake
# real (59).jpg: Prob (Fake) = 0.4954, Predicted = Real
# fake (38).jpg: Prob (Fake) = 0.9556, Predicted = Fake
# real (25).jpg: Prob (Fake) = 0.0769, Predicted = Real
# fake (7).jpg: Prob (Fake) = 0.1629, Predicted = Real
# fake (30).jpg: Prob (Fake) = 0.9047, Predicted = Fake
# real (33).jpg: Prob (Fake) = 0.0002, Predicted = Real
# fake (32).jpg: Prob (Fake) = 0.8397, Predicted = Fake
# fake (35).jpg: Prob (Fake) = 0.9599, Predicted = Fake
# fake (46).jpg: Prob (Fake) = 0.2397, Predicted = Real
# fake (4).jpg: Prob (Fake) = 0.1883, Predicted = Real
# fake (42).jpg: Prob (Fake) = 0.7820, Predicted = Fake
# fake (9).jpg: Prob (Fake) = 0.6168, Predicted = Fake
# fake (21).jpg: Prob (Fake) = 0.9743, Predicted = Fake
# fake (24).jpg: Prob (Fake) = 0.9222, Predicted = Fake
# real (22).jpg: Prob (Fake) = 0.4164, Predicted = Real
# fake (8).jpg: Prob (Fake) = 0.8580, Predicted = Fake
# real (7).jpg: Prob (Fake) = 0.0371, Predicted = Real
# real (55).jpg: Prob (Fake) = 0.1361, Predicted = Real
# fake (48).jpg: Prob (Fake) = 0.1134, Predicted = Real
# real (9).jpg: Prob (Fake) = 0.4762, Predicted = Real
# real (50).jpg: Prob (Fake) = 0.0629, Predicted = Real
# real (38).jpg: Prob (Fake) = 0.8970, Predicted = Fake
# fake (23).jpg: Prob (Fake) = 0.7568, Predicted = Fake
# real (2).jpg: Prob (Fake) = 0.1776, Predicted = Real
# real (17).jpg: Prob (Fake) = 0.1179, Predicted = Real
# fake (40).jpg: Prob (Fake) = 0.9852, Predicted = Fake
# fake (31).jpg: Prob (Fake) = 0.6872, Predicted = Fake
# real (16).jpg: Prob (Fake) = 0.2211, Predicted = Real
# fake (45).jpg: Prob (Fake) = 0.9881, Predicted = Fake
# real (31).jpg: Prob (Fake) = 0.1233, Predicted = Real
# real (6).jpg: Prob (Fake) = 0.0036, Predicted = Real
# real (40).jpg: Prob (Fake) = 0.4460, Predicted = Real
# fake (25).jpg: Prob (Fake) = 0.5157, Predicted = Fake
# fake (28).jpg: Prob (Fake) = 0.9778, Predicted = Fake
# fake (47).jpg: Prob (Fake) = 0.9877, Predicted = Fake
# fake (20).jpg: Prob (Fake) = 0.5527, Predicted = Fake
# real (45).jpg: Prob (Fake) = 0.5574, Predicted = Fake
# fake (1).jpg: Prob (Fake) = 0.8473, Predicted = Fake
# fake (55).jpg: Prob (Fake) = 0.7140, Predicted = Fake
# fake (44).jpg: Prob (Fake) = 0.9925, Predicted = Fake
# fake (60).jpg: Prob (Fake) = 0.9265, Predicted = Fake
# fake (39).jpg: Prob (Fake) = 0.0826, Predicted = Real
# real (56).jpg: Prob (Fake) = 0.3613, Predicted = Real
# real (19).jpg: Prob (Fake) = 0.0688, Predicted = Real
# real (1).jpg: Prob (Fake) = 0.0162, Predicted = Real
# fake (56).jpg: Prob (Fake) = 0.2383, Predicted = Real
# fake (37).jpg: Prob (Fake) = 0.9388, Predicted = Fake
# real (36).jpg: Prob (Fake) = 0.9371, Predicted = Fake
# real (5).jpg: Prob (Fake) = 0.0811, Predicted = Real
# real (34).jpg: Prob (Fake) = 0.0033, Predicted = Real
# real (15).jpg: Prob (Fake) = 0.9875, Predicted = Fake
# fake (17).jpg: Prob (Fake) = 0.6844, Predicted = Fake
# fake (27).jpg: Prob (Fake) = 0.9797, Predicted = Fake
# real (20).jpg: Prob (Fake) = 0.0400, Predicted = Real
# fake (36).jpg: Prob (Fake) = 0.9440, Predicted = Fake
# fake (51).jpg: Prob (Fake) = 0.9786, Predicted = Fake
# real (51).jpg: Prob (Fake) = 0.0108, Predicted = Real
# real (48).jpg: Prob (Fake) = 0.0993, Predicted = Real
# fake (5).jpg: Prob (Fake) = 0.9491, Predicted = Fake
# real (54).jpg: Prob (Fake) = 0.0216, Predicted = Real
# real (12).jpg: Prob (Fake) = 0.8150, Predicted = Fake
# real (18).jpg: Prob (Fake) = 0.6301, Predicted = Fake
# fake (6).jpg: Prob (Fake) = 0.6527, Predicted = Fake
# fake (58).jpg: Prob (Fake) = 0.8513, Predicted = Fake
# fake (16).jpg: Prob (Fake) = 0.9432, Predicted = Fake
# fake (34).jpg: Prob (Fake) = 0.9593, Predicted = Fake
# fake (49).jpg: Prob (Fake) = 0.7381, Predicted = Fake
# real (37).jpg: Prob (Fake) = 0.9051, Predicted = Fake
# fake (29).jpg: Prob (Fake) = 0.8184, Predicted = Fake
# real (46).jpg: Prob (Fake) = 0.9351, Predicted = Fake
# fake (57).jpg: Prob (Fake) = 0.9867, Predicted = Fake
# fake (53).jpg: Prob (Fake) = 0.9864, Predicted = Fake
# fake (41).jpg: Prob (Fake) = 0.8005, Predicted = Fake
# real (44).jpg: Prob (Fake) = 0.0536, Predicted = Real
# real (24).jpg: Prob (Fake) = 0.5216, Predicted = Fake
# real (35).jpg: Prob (Fake) = 0.3884, Predicted = Real
# real (30).jpg: Prob (Fake) = 0.1508, Predicted = Real
# real (28).jpg: Prob (Fake) = 0.0987, Predicted = Real
# fake (2).jpg: Prob (Fake) = 0.9784, Predicted = Fake
# fake (18).jpg: Prob (Fake) = 0.6145, Predicted = Fake
# real (43).jpg: Prob (Fake) = 0.3115, Predicted = Real
# real (60).jpg: Prob (Fake) = 0.1537, Predicted = Real
# fake (11).jpg: Prob (Fake) = 0.5203, Predicted = Fake
# real (3).jpg: Prob (Fake) = 0.0007, Predicted = Real
# real (49).jpg: Prob (Fake) = 0.6135, Predicted = Fake
# real (57).jpg: Prob (Fake) = 0.1945, Predicted = Real
# real (11).jpg: Prob (Fake) = 0.2528, Predicted = Real
# real (53).jpg: Prob (Fake) = 0.5387, Predicted = Fake
# real (41).jpg: Prob (Fake) = 0.2892, Predicted = Real
# real (8).jpg: Prob (Fake) = 0.1940, Predicted = Real
# fake (59).jpg: Prob (Fake) = 0.8514, Predicted = Fake
# fake (3).jpg: Prob (Fake) = 0.3126, Predicted = Real
# fake (19).jpg: Prob (Fake) = 0.9859, Predicted = Fake
# fake (50).jpg: Prob (Fake) = 0.4722, Predicted = Real
# fake (22).jpg: Prob (Fake) = 0.7318, Predicted = Fake
# real (58).jpg: Prob (Fake) = 0.5381, Predicted = Fake
# real (27).jpg: Prob (Fake) = 0.8341, Predicted = Fake
# fake (10).jpg: Prob (Fake) = 0.8700, Predicted = Fake
# real (52).jpg: Prob (Fake) = 0.0653, Predicted = Real
# fake (15).jpg: Prob (Fake) = 0.5936, Predicted = Fake
# real (47).jpg: Prob (Fake) = 0.7297, Predicted = Fake
# real (21).jpg: Prob (Fake) = 0.0057, Predicted = Real
#
#  Project Finished

# %%
# Predict and Visualize Multiple Images

import os
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.models import load_model

model_filename = "fold_4_phase2_best_model.keras" #update if needed
model_path_for_prediction = os.path.join(CONFIG["MODEL_SAVE_DIR"], model_filename)


# Specify the paths to the images you want to predict on
image_paths_for_prediction = [
    r"/kaggle/input/rvf10k/rvf10k/train/fake/LJE2ZPJRWX.jpg", #update if needed
    r"/kaggle/input/rvf10k/rvf10k/train/real/46915.jpg",      #update if needed
    # Add more image paths to this list with the same indentation as the lines above
]

# Load the model
print(f"Attempting to load model from: {model_path_for_prediction}")
try:
    prediction_model = load_trained_model(model_path_for_prediction)
    model_loaded_successfully = True
except FileNotFoundError:
    print(f"\n Error: Model file not found at {model_path_for_prediction}.")
    print("Please ensure you have trained a model and the path is correct.")
    model_loaded_successfully = False # Flag failure
    prediction_model = None # Explicitly set to None
except Exception as e:
    print(f"\n An error occurred while loading the model: {e}")
    model_loaded_successfully = False # Flag failure
    prediction_model = None


#  Make and Visualize Predictions (if model loaded successfully)
if model_loaded_successfully and prediction_model:
    print(f"\nMaking predictions for {len(image_paths_for_prediction)} images:")
    for i, image_path in enumerate(image_paths_for_prediction):
        print(f"\n Predicting on Image {i+1}/{len(image_paths_for_prediction)}: {os.path.basename(image_path)} -----")
        prob, label = predict_single_image(prediction_model, image_path, CONFIG)

else:
    print("\n Skipping prediction as the model could not be loaded.")
# Out:
# Attempting to load model from: /kaggle/working/mymodels/fold_4_phase2_best_model.keras
# Loading model from: /kaggle/working/mymodels/fold_4_phase2_best_model.keras
# Model loaded.
#
# Making predictions for 2 images:
#
#  Predicting on Image 1/2: LJE2ZPJRWX.jpg -----
# Prediction for LJE2ZPJRWX.jpg: Prob (Fake) = 0.9294, Predicted = Fake
#
#  Predicting on Image 2/2: 46915.jpg -----
# Prediction for 46915.jpg: Prob (Fake) = 0.0561, Predicted = Real
